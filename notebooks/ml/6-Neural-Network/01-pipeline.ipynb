# %%
import numpy as np

# %%
# 输入聚合

# %%
x = [[1,2,3],[4,5,6]]
w = [5,3,1]
b = 1
def input_ensemble(x, w, b):
    y = list(map(lambda z: z + 1, np.dot(a,w)))
    print(y)
    return y
# Out:
# [15, 42]

# %%
# 激活函数
# logistic/tanh/高斯/softmax
# relu/hard-max

def activate(x, args):
    print(x)
    print(args)
    if args=='relu':
        def relu(tmp):
            if tmp > 0:
                return tmp
            else:
                return 0
        return list(map(lambda z: relu(z), x))
    elif args == 'tanh':
        def tanh(tmp):
            return (np.exp(tmp) - np.exp(-tmp))/(np.exp(tmp) + np.exp(-tmp))
        return list(map(lambda z: tanh(z), x))
    elif args == 'sigmoid':
        def sigmoid(tmp):
            return 1/(1+np.exp(-tmp))
        return list(map(lambda z: sigmoid(z), x))

print(activate(y, 'sigmoid'))
# Out:
# [15, 42]
# sigmoid
# [0.999999694097773, 1.0]

# %%
# 感知机

# %%
# loss 计算
# 1. [均方差（MSE）](#均方差mse)
#     2. [平均绝对差(MAE)](#平均绝对差mae)
#     3. [交叉熵损失(Cross Entorpy)  针对 S 型激活函数](#交叉熵损失cross-entorpy--针对-s-型激活函数)
#     4. [Hinge Loss](#hinge-loss)
#     5. [KL](#kl)
#     6. [focal loss](#focal-loss)
#     7. [tensorflow loss](#tensorflow-loss)
#         1. [tf.nn.sigmoid_cross_entropy_with_logits()](#tfnnsigmoid_cross_entropy_with_logits)
#         2. [tf.nn.softmax_cross_entropy_with_logits()](#tfnnsoftmax_cross_entropy_with_logits)
#         3. [Weighted cross entropy with logits](#weighted-cross-entropy-with-logits)
#         4. [nce](#nce)
#         5. [sampled_softmax_loss](#sampled_softmax_loss)
#         6. [sequence_loss_by_example](#sequence_loss_by_example)

# %% [markdown]
# 1. [RBF](#rbf)
# 2. [ART](#art)
# 3. [SOM](#som)
# 4. [级联相关网络](#级联相关网络)
# 5. [Elman](#elman)
# 6. [Boltzmannn](#boltzmannn)

# %%
# BP 网络

# %%
# RBF 网络

# %%
# Boltzman
+ https://blog.csdn.net/jyh_AI/article/details/82049822
