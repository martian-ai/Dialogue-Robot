# %%
import logging
import sys
import numpy as np
sys.path.append('..')
from function import GibbsLDA
from function import vbLDA
from function.utils import convert_cnt_to_list, get_top_words, get_corpus_ids_cnt

# %%
# 文件路径
corpus_path = '../../../../resources/corpus/solutions/mining_qa/sentiment/0103.txt'
vocab_path = '../../../../resources/vocab/vocab_tmp' 
stopwords_path = '../../../../resources/vocab/stopwords_hit_copy.txt'
# 参数设计
num_doc = 10000 # 文档个数 
max_voca = 6000 # 词典个数
max_iter = 100 # 迭代轮数(TODO 参数优化)
n_topic = 30 # 主题个数(TODO 参数优化，借鉴CRP DPMM 等)

# %%
# 通过原始语料构造训练数据
lines, (voca, doc_ids, doc_cnt) = get_corpus_ids_cnt(corpus_path=corpus_path, vocab_path=vocab_path, stopwords_path=stopwords_path, num_doc=num_doc, max_voca=max_voca)
docs = convert_cnt_to_list(doc_ids, doc_cnt)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/dz/0yc_qtt536x7_tgb5wb5phg40000gn/T/jieba.cache
# Loading model cost 0.465 seconds.
# Prefix dict has been built successfully.

# %%
print(lines[:5])
# Out:
# ['哈哈', '嘿嘿嘿', '嘻嘻', '嘿嘿', '我爱你']

# %%
model = GibbsLDA(len(docs), len(voca), n_topic)
model.fit(docs, max_iter=max_iter)
model.save('tmp.pkl')
# Out:
# 2023-01-05 16:52:13 INFO:GibbsLDA:[ITER] 0,	elapsed time:0.14,	log_likelihood:-126437.41
# 2023-01-05 16:52:13 INFO:GibbsLDA:[ITER] 1,	elapsed time:0.14,	log_likelihood:-118751.24
# 2023-01-05 16:52:13 INFO:GibbsLDA:[ITER] 2,	elapsed time:0.14,	log_likelihood:-113948.64
# 2023-01-05 16:52:13 INFO:GibbsLDA:[ITER] 3,	elapsed time:0.14,	log_likelihood:-110044.93
# 2023-01-05 16:52:13 INFO:GibbsLDA:[ITER] 4,	elapsed time:0.14,	log_likelihood:-106923.89
# 2023-01-05 16:52:14 INFO:GibbsLDA:[ITER] 5,	elapsed time:0.14,	log_likelihood:-104778.37
# 2023-01-05 16:52:14 INFO:GibbsLDA:[ITER] 6,	elapsed time:0.16,	log_likelihood:-102465.01
# 2023-01-05 16:52:14 INFO:GibbsLDA:[ITER] 7,	elapsed time:0.14,	log_likelihood:-100574.51
# 2023-01-05 16:52:14 INFO:GibbsLDA:[ITER] 8,	elapsed time:0.14,	log_likelihood:-99335.32
# 2023-01-05 16:52:14 INFO:GibbsLDA:[ITER] 9,	elapsed time:0.14,	log_likelihood:-98187.82
# 2023-01-05 16:52:15 INFO:GibbsLDA:[ITER] 10,	elapsed time:0.14,	log_likelihood:-97303.62
# 2023-01-05 16:52:15 INFO:GibbsLDA:[ITER] 11,	elapsed time:0.14,	log_likelihood:-96483.98
# 2023-01-05 16:52:15 INFO:GibbsLDA:[ITER] 12,	elapsed time:0.14,	log_likelihood:-95704.29
# 2023-01-05 16:52:15 INFO:GibbsLDA:[ITER] 13,	elapsed time:0.14,	log_likelihood:-95373.56
# 2023-01-05 16:52:15 INFO:GibbsLDA:[ITER] 14,	elapsed time:0.14,	log_likelihood:-94568.01
# 2023-01-05 16:52:15 INFO:GibbsLDA:[ITER] 15,	elapsed time:0.14,	log_likelihood:-94119.70
# 2023-01-05 16:52:16 INFO:GibbsLDA:[ITER] 16,	elapsed time:0.14,	log_likelihood:-93833.14
# 2023-01-05 16:52:16 INFO:GibbsLDA:[ITER] 17,	elapsed time:0.14,	log_likelihood:-93294.38
# 2023-01-05 16:52:16 INFO:GibbsLDA:[ITER] 18,	elapsed time:0.15,	log_likelihood:-92855.18
# 2023-01-05 16:52:16 INFO:GibbsLDA:[ITER] 19,	elapsed time:0.14,	log_likelihood:-92461.62
# 2023-01-05 16:52:16 INFO:GibbsLDA:[ITER] 20,	elapsed time:0.15,	log_likelihood:-91777.43
# 2023-01-05 16:52:17 INFO:GibbsLDA:[ITER] 21,	elapsed time:0.14,	log_likelihood:-91362.59
# 2023-01-05 16:52:17 INFO:GibbsLDA:[ITER] 22,	elapsed time:0.15,	log_likelihood:-91115.74
# 2023-01-05 16:52:17 INFO:GibbsLDA:[ITER] 23,	elapsed time:0.14,	log_likelihood:-90887.38
# 2023-01-05 16:52:17 INFO:GibbsLDA:[ITER] 24,	elapsed time:0.14,	log_likelihood:-90698.45
# 2023-01-05 16:52:17 INFO:GibbsLDA:[ITER] 25,	elapsed time:0.15,	log_likelihood:-90751.75
# 2023-01-05 16:52:18 INFO:GibbsLDA:[ITER] 26,	elapsed time:0.14,	log_likelihood:-90480.10
# 2023-01-05 16:52:18 INFO:GibbsLDA:[ITER] 27,	elapsed time:0.14,	log_likelihood:-90344.26
# 2023-01-05 16:52:18 INFO:GibbsLDA:[ITER] 28,	elapsed time:0.14,	log_likelihood:-90080.40
# 2023-01-05 16:52:18 INFO:GibbsLDA:[ITER] 29,	elapsed time:0.14,	log_likelihood:-89910.86
# 2023-01-05 16:52:18 INFO:GibbsLDA:[ITER] 30,	elapsed time:0.14,	log_likelihood:-89699.95
# 2023-01-05 16:52:18 INFO:GibbsLDA:[ITER] 31,	elapsed time:0.14,	log_likelihood:-89443.39
# 2023-01-05 16:52:19 INFO:GibbsLDA:[ITER] 32,	elapsed time:0.14,	log_likelihood:-89575.62
# 2023-01-05 16:52:19 INFO:GibbsLDA:[ITER] 33,	elapsed time:0.14,	log_likelihood:-89539.11
# 2023-01-05 16:52:19 INFO:GibbsLDA:[ITER] 34,	elapsed time:0.14,	log_likelihood:-89178.51
# 2023-01-05 16:52:19 INFO:GibbsLDA:[ITER] 35,	elapsed time:0.14,	log_likelihood:-88951.20
# 2023-01-05 16:52:19 INFO:GibbsLDA:[ITER] 36,	elapsed time:0.14,	log_likelihood:-88749.16
# 2023-01-05 16:52:20 INFO:GibbsLDA:[ITER] 37,	elapsed time:0.14,	log_likelihood:-88936.08
# 2023-01-05 16:52:20 INFO:GibbsLDA:[ITER] 38,	elapsed time:0.14,	log_likelihood:-89027.64
# 2023-01-05 16:52:20 INFO:GibbsLDA:[ITER] 39,	elapsed time:0.14,	log_likelihood:-89117.20
# 2023-01-05 16:52:20 INFO:GibbsLDA:[ITER] 40,	elapsed time:0.14,	log_likelihood:-89012.61
# 2023-01-05 16:52:20 INFO:GibbsLDA:[ITER] 41,	elapsed time:0.14,	log_likelihood:-88974.98
# 2023-01-05 16:52:21 INFO:GibbsLDA:[ITER] 42,	elapsed time:0.14,	log_likelihood:-88978.05
# 2023-01-05 16:52:21 INFO:GibbsLDA:[ITER] 43,	elapsed time:0.14,	log_likelihood:-89173.57
# 2023-01-05 16:52:21 INFO:GibbsLDA:[ITER] 44,	elapsed time:0.14,	log_likelihood:-89024.59
# 2023-01-05 16:52:21 INFO:GibbsLDA:[ITER] 45,	elapsed time:0.14,	log_likelihood:-88961.45
# 2023-01-05 16:52:21 INFO:GibbsLDA:[ITER] 46,	elapsed time:0.14,	log_likelihood:-88963.25
# 2023-01-05 16:52:21 INFO:GibbsLDA:[ITER] 47,	elapsed time:0.14,	log_likelihood:-88719.38
# 2023-01-05 16:52:22 INFO:GibbsLDA:[ITER] 48,	elapsed time:0.14,	log_likelihood:-88825.75
# 2023-01-05 16:52:22 INFO:GibbsLDA:[ITER] 49,	elapsed time:0.14,	log_likelihood:-88745.59
# 2023-01-05 16:52:22 INFO:GibbsLDA:[ITER] 50,	elapsed time:0.14,	log_likelihood:-88733.48
# 2023-01-05 16:52:22 INFO:GibbsLDA:[ITER] 51,	elapsed time:0.14,	log_likelihood:-88515.72
# 2023-01-05 16:52:22 INFO:GibbsLDA:[ITER] 52,	elapsed time:0.14,	log_likelihood:-88397.61
# 2023-01-05 16:52:23 INFO:GibbsLDA:[ITER] 53,	elapsed time:0.14,	log_likelihood:-88479.54
# 2023-01-05 16:52:23 INFO:GibbsLDA:[ITER] 54,	elapsed time:0.14,	log_likelihood:-88670.50
# 2023-01-05 16:52:23 INFO:GibbsLDA:[ITER] 55,	elapsed time:0.14,	log_likelihood:-88449.52
# 2023-01-05 16:52:23 INFO:GibbsLDA:[ITER] 56,	elapsed time:0.14,	log_likelihood:-88324.14
# 2023-01-05 16:52:23 INFO:GibbsLDA:[ITER] 57,	elapsed time:0.14,	log_likelihood:-88169.32
# 2023-01-05 16:52:23 INFO:GibbsLDA:[ITER] 58,	elapsed time:0.14,	log_likelihood:-88292.35
# 2023-01-05 16:52:24 INFO:GibbsLDA:[ITER] 59,	elapsed time:0.14,	log_likelihood:-88100.16
# 2023-01-05 16:52:24 INFO:GibbsLDA:[ITER] 60,	elapsed time:0.14,	log_likelihood:-88039.56
# 2023-01-05 16:52:24 INFO:GibbsLDA:[ITER] 61,	elapsed time:0.14,	log_likelihood:-88129.72
# 2023-01-05 16:52:24 INFO:GibbsLDA:[ITER] 62,	elapsed time:0.14,	log_likelihood:-87964.82
# 2023-01-05 16:52:24 INFO:GibbsLDA:[ITER] 63,	elapsed time:0.14,	log_likelihood:-87918.69
# 2023-01-05 16:52:25 INFO:GibbsLDA:[ITER] 64,	elapsed time:0.14,	log_likelihood:-87940.37
# 2023-01-05 16:52:25 INFO:GibbsLDA:[ITER] 65,	elapsed time:0.14,	log_likelihood:-87672.66
# 2023-01-05 16:52:25 INFO:GibbsLDA:[ITER] 66,	elapsed time:0.14,	log_likelihood:-87834.11
# 2023-01-05 16:52:25 INFO:GibbsLDA:[ITER] 67,	elapsed time:0.14,	log_likelihood:-87889.85
# 2023-01-05 16:52:25 INFO:GibbsLDA:[ITER] 68,	elapsed time:0.14,	log_likelihood:-87782.58
# 2023-01-05 16:52:26 INFO:GibbsLDA:[ITER] 69,	elapsed time:0.14,	log_likelihood:-87857.02
# 2023-01-05 16:52:26 INFO:GibbsLDA:[ITER] 70,	elapsed time:0.14,	log_likelihood:-87550.67
# 2023-01-05 16:52:26 INFO:GibbsLDA:[ITER] 71,	elapsed time:0.14,	log_likelihood:-87509.22
# 2023-01-05 16:52:26 INFO:GibbsLDA:[ITER] 72,	elapsed time:0.14,	log_likelihood:-87378.65
# 2023-01-05 16:52:26 INFO:GibbsLDA:[ITER] 73,	elapsed time:0.14,	log_likelihood:-87374.73
# 2023-01-05 16:52:26 INFO:GibbsLDA:[ITER] 74,	elapsed time:0.14,	log_likelihood:-87523.33
# 2023-01-05 16:52:27 INFO:GibbsLDA:[ITER] 75,	elapsed time:0.14,	log_likelihood:-87501.44
# 2023-01-05 16:52:27 INFO:GibbsLDA:[ITER] 76,	elapsed time:0.14,	log_likelihood:-87591.82
# 2023-01-05 16:52:27 INFO:GibbsLDA:[ITER] 77,	elapsed time:0.14,	log_likelihood:-87524.14
# 2023-01-05 16:52:27 INFO:GibbsLDA:[ITER] 78,	elapsed time:0.14,	log_likelihood:-87554.99
# 2023-01-05 16:52:27 INFO:GibbsLDA:[ITER] 79,	elapsed time:0.14,	log_likelihood:-87537.12
# 2023-01-05 16:52:28 INFO:GibbsLDA:[ITER] 80,	elapsed time:0.14,	log_likelihood:-87570.28
# 2023-01-05 16:52:28 INFO:GibbsLDA:[ITER] 81,	elapsed time:0.14,	log_likelihood:-87512.61
# 2023-01-05 16:52:28 INFO:GibbsLDA:[ITER] 82,	elapsed time:0.14,	log_likelihood:-87462.15
# 2023-01-05 16:52:28 INFO:GibbsLDA:[ITER] 83,	elapsed time:0.14,	log_likelihood:-87125.78
# 2023-01-05 16:52:28 INFO:GibbsLDA:[ITER] 84,	elapsed time:0.14,	log_likelihood:-87282.63
# 2023-01-05 16:52:29 INFO:GibbsLDA:[ITER] 85,	elapsed time:0.14,	log_likelihood:-87159.13
# 2023-01-05 16:52:29 INFO:GibbsLDA:[ITER] 86,	elapsed time:0.14,	log_likelihood:-87160.91
# 2023-01-05 16:52:29 INFO:GibbsLDA:[ITER] 87,	elapsed time:0.14,	log_likelihood:-87350.19
# 2023-01-05 16:52:29 INFO:GibbsLDA:[ITER] 88,	elapsed time:0.14,	log_likelihood:-87325.77
# 2023-01-05 16:52:29 INFO:GibbsLDA:[ITER] 89,	elapsed time:0.14,	log_likelihood:-87449.43
# 2023-01-05 16:52:29 INFO:GibbsLDA:[ITER] 90,	elapsed time:0.14,	log_likelihood:-87182.00
# 2023-01-05 16:52:30 INFO:GibbsLDA:[ITER] 91,	elapsed time:0.14,	log_likelihood:-87154.67
# 2023-01-05 16:52:30 INFO:GibbsLDA:[ITER] 92,	elapsed time:0.14,	log_likelihood:-86921.65
# 2023-01-05 16:52:30 INFO:GibbsLDA:[ITER] 93,	elapsed time:0.14,	log_likelihood:-86849.15
# 2023-01-05 16:52:30 INFO:GibbsLDA:[ITER] 94,	elapsed time:0.14,	log_likelihood:-87055.39
# 2023-01-05 16:52:30 INFO:GibbsLDA:[ITER] 95,	elapsed time:0.14,	log_likelihood:-87104.53
# 2023-01-05 16:52:31 INFO:GibbsLDA:[ITER] 96,	elapsed time:0.14,	log_likelihood:-86851.34
# 2023-01-05 16:52:31 INFO:GibbsLDA:[ITER] 97,	elapsed time:0.14,	log_likelihood:-86800.48
# 2023-01-05 16:52:31 INFO:GibbsLDA:[ITER] 98,	elapsed time:0.14,	log_likelihood:-86802.71
# 2023-01-05 16:52:31 INFO:GibbsLDA:[ITER] 99,	elapsed time:0.14,	log_likelihood:-86852.39

# %%
# 显示每个主题的关键词
for ti in range(n_topic):
    top_words = get_top_words(model.TW, voca, ti, n_words=5)
    print('Topic', ti ,': ', ','.join(top_words))
# Out:
# Topic 0 :  也,就,不,说,嘛
# Topic 1 :  爱,人,最,她,乱
# Topic 2 :  吗,靠,别,能,被
# Topic 3 :  不,人,吗,还,让
# Topic 4 :  说,跟,没,又,哼
# Topic 5 :  在,呀,那,讲,妹
# Topic 6 :  唉,要,去,看,走
# Topic 7 :  来,呸,给,把,呵
# Topic 8 :  说,不,就,丑,骂
# Topic 9 :  真,想,笑,揍,可
# Topic 10 :  那,就,吗,吃,呀
# Topic 11 :  说,还,么,看,咋
# Topic 12 :  想,很,和,做,打
# Topic 13 :  他,骂,要,跟,她
# Topic 14 :  个,吵,臭,太,用
# Topic 15 :  去,给,打,就,找
# Topic 16 :  嗯,在,说,个,惹
# Topic 17 :  啦,聋,八,拉,改
# Topic 18 :  个,吗,猪,狗,帅
# Topic 19 :  呢,笨,还,很,咋
# Topic 20 :  太,这,也,吧,哇
# Topic 21 :  吧,好,呀,哭,疯
# Topic 22 :  不,啥,呀,对,说
# Topic 23 :  个,大,鬼,才,怪
# Topic 24 :  没,这,都,哎,还
# Topic 25 :  好,哦,很,爱,哟
# Topic 26 :  有,吗,病,吧,会
# Topic 27 :  谁,呀,叫,都,烦
# Topic 28 :  听,不,要,哈,着
# Topic 29 :  不,都,跟,玩,懂

# %%
# 聚类结果展示前10条
topic_results = model.inference(docs, max_iter=10) 
cluster_results = []
new_cluster_results = []
for topic, line in zip(topic_results, lines):
    topic = topic.tolist()
    cluster_results.append((topic.index(max(topic)), line))
    new_cluster_results = sorted(cluster_results, key=lambda k:k[0])

# %%
cluster_results[:5]
# Out:
# [(0, '哈哈'), (0, '嘿嘿嘿'), (0, '嘻嘻'), (0, '嘿嘿'), (0, '我爱你')]

# %%
for item in new_cluster_results:
    print(item)
# Out:
# (0, '哈哈')
# (0, '嘿嘿嘿')
# (0, '嘻嘻')
# (0, '嘿嘿')
# (0, '我爱你')
# (0, '哈哈哈哈哈哈哈哈')
# (0, '哈哈哈哈哈')
# (0, '哈哈哈')
# (0, '讨厌')
# (0, '哈哈哈哈哈哈哈')
# (0, '哈哈哈哈')
# (0, '我喜欢')
# (0, '你真笨')
# (0, '笨蛋')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈哈哈')
# (0, '嘿嘿嘿嘿嘿嘿嘿')
# (0, '嘿嘿嘿嘿嘿嘿')
# (0, '哼哼哼哼哼哼')
# (0, '哈哈哈哈哈哈')
# (0, '嘿嘿嘿嘿')
# (0, '你太笨了')
# (0, '你真棒')
# (0, '真笨')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '哼哼哼哼哼哼哼哼哼哼')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '呵呵呵呵呵呵')
# (0, '你是不是笨蛋')
# (0, '嘿嘿嘿嘿嘿')
# (0, '你是笨蛋')
# (0, '神经病')
# (0, '我哈哈')
# (0, '太笨了')
# (0, '你笨蛋')
# (0, '垃圾')
# (0, '喜欢')
# (0, '哈哈哈哈哈哈哈哈哈')
# (0, '我爱你我爱你')
# (0, '哈哈哈哈嘿嘿')
# (0, '你这个笨蛋')
# (0, '你神经病啊')
# (0, '你是大坏蛋')
# (0, '你太烦人了')
# (0, '这个笨蛋')
# (0, '说你大爷')
# (0, '神经病啊')
# (0, '我生气了')
# (0, '喜欢你')
# (0, '哈哈啊')
# (0, '别吵了')
# (0, '你妹啊')
# (0, '你太笨')
# (0, '麻烦')
# (0, '烦人')
# (0, '废话')
# (0, '帅哥')
# (0, '呜呜')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哼哼哼哼哼哼哼哼')
# (0, '老婆老婆我爱你')
# (0, '我也喜欢你')
# (0, '我不理你了')
# (0, '你别说话了')
# (0, '伤心太平洋')
# (0, '笨蛋笨蛋')
# (0, '我喜欢的')
# (0, '你太丑了')
# (0, '你别说话')
# (0, '生气了')
# (0, '漂亮的')
# (0, '我烦你')
# (0, '小可爱')
# (0, '对不起')
# (0, '太棒了')
# (0, '你真帅')
# (0, '你好看')
# (0, '真棒')
# (0, '混蛋')
# (0, '坑爹')
# (0, '伤心')
# (0, '烦')
# (0, '哼哼哼哼哼哼哼哼哼哼哼哼哼哼哼哼哼哼')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '哼哼哼哼哼哼哼哼哼哼哼哼哼哼')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '哈哈哈哈哈哈哈哈哈哈哈')
# (0, '你这个小笨蛋')
# (0, '你反应太慢了')
# (0, '我生气了啊')
# (0, '我心情不好')
# (0, '我喜欢紫色')
# (0, '我冷静不了')
# (0, '偏偏喜欢你')
# (0, '我失恋了')
# (0, '我喜欢你')
# (0, '哈哈谢谢')
# (0, '你生气了')
# (0, '你好笨啊')
# (0, '你好漂亮')
# (0, '你太蠢了')
# (0, '你大爷的')
# (0, '人工智障')
# (0, '不想说话')
# (0, '讨厌你')
# (0, '我厉害')
# (0, '好烦啊')
# (0, '你走开')
# (0, '你讨厌')
# (0, '你白痴')
# (0, '你最美')
# (0, '你最丑')
# (0, '你很棒')
# (0, '你好笨')
# (0, '靠靠')
# (0, '白痴')
# (0, '漂亮')
# (0, '害怕')
# (0, '可爱')
# (0, '可怜')
# (0, '别吵')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿哈哈哈')
# (0, '呵呵呵呵呵呵呵呵呵呵')
# (0, '呵呵呵呵呵呵呵呵')
# (0, '闭上你的嘴巴')
# (0, '想着你亲爱的')
# (0, '嘿嘿嘿哈哈哈')
# (0, '哈哈哈哈退出')
# (0, '呵呵哈哈哈哈')
# (0, '耶耶耶耶耶')
# (0, '老婆我爱你')
# (0, '我爱你中国')
# (0, '我也很高兴')
# (0, '你脑子有病')
# (0, '你才神经病')
# (0, '我讨厌你')
# (0, '哼哼哼哼')
# (0, '哎呀妈呀')
# (0, '哈哈呵呵')
# (0, '哈哈你好')
# (0, '呵呵笨蛋')
# (0, '呵呵嘿嘿')
# (0, '呵呵哈哈')
# (0, '你神经病')
# (0, '你真笨啊')
# (0, '你是智障')
# (0, '你是小狗')
# (0, '你是坏蛋')
# (0, '你好讨厌')
# (0, '你好无聊')
# (0, '你太烦了')
# (0, '你不要脸')
# (0, '不要说话')
# (0, '害怕了')
# (0, '好笨啊')
# (0, '大坏蛋')
# (0, '你说话')
# (0, '你真坏')
# (0, '你真乖')
# (0, '你很烦')
# (0, '你好坏')
# (0, '你坏蛋')
# (0, '你喜欢')
# (0, '不理你')
# (0, '骂人')
# (0, '美女')
# (0, '笨笨')
# (0, '最美')
# (0, '恶心')
# (0, '心疼')
# (0, '很棒')
# (0, '宝贝')
# (0, '妈蛋')
# (0, '好赞')
# (0, '好烦')
# (0, '乖乖')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哼哼哼哼哼哼哼哼哼哼哼哼')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '哈哈哈哈哈哈哈哈呵呵')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '啊哈哈哈哈哈哈哈')
# (0, '你是不是人工智障')
# (0, '呵呵呵呵哈哈哈')
# (0, '生气了怎么办')
# (0, '我喜欢粉红色')
# (0, '我也在想你呀')
# (0, '喜欢你喜欢你')
# (0, '你长得好丑啊')
# (0, '你真的太笨了')
# (0, '你是不是脑残')
# (0, '你是不是白痴')
# (0, '你大爷你大爷')
# (0, '你也太笨了吧')
# (0, '我的小宝贝')
# (0, '我喜欢你啊')
# (0, '嘿嘿嘿哈哈')
# (0, '啊哈哈哈哈')
# (0, '你这个坏蛋')
# (0, '你是神经病')
# (0, '你不要说话')
# (0, '什么玩意儿')
# (0, '不要说话了')
# (0, '这么厉害')
# (0, '挺好看的')
# (0, '我肚子疼')
# (0, '心情不好')
# (0, '对不起啊')
# (0, '宝贝宝贝')
# (0, '嘿嘿好好')
# (0, '嘿嘿呵呵')
# (0, '嘻嘻嘻嘻')
# (0, '你烦不烦')
# (0, '你是笨猪')
# (0, '你好烦人')
# (0, '你太坏了')
# (0, '乖乖乖乖')
# (0, '不理你了')
# (0, '不想理你')
# (0, '胆小鬼')
# (0, '耶耶耶')
# (0, '算你狠')
# (0, '我难过')
# (0, '我生气')
# (0, '我害怕')
# (0, '我好烦')
# (0, '小笨蛋')
# (0, '小宝贝')
# (0, '好萌啊')
# (0, '太委屈')
# (0, '太坏了')
# (0, '喜欢的')
# (0, '啊哈哈')
# (0, '受不了')
# (0, '你真烦')
# (0, '你混蛋')
# (0, '你废话')
# (0, '不要脸')
# (0, '遗憾')
# (0, '贱人')
# (0, '笨猪')
# (0, '笑笑')
# (0, '神经')
# (0, '欠揍')
# (0, '悲哀')
# (0, '好哇')
# (0, '危险')
# (0, '呵呵呵呵呵呵呵呵打开爱奇艺')
# (0, '嘿嘿嘿嘿嘿嘿哈哈哈哈哈')
# (0, '呵呵呵呵呵呵呵呵好吃')
# (0, '周末回家了哈哈哈哈哈')
# (0, '头疼啊头疼啊头疼啊')
# (0, '呵呵哈哈哈哈哈哈哈')
# (0, '你脑子是不是瓦特了')
# (0, '什么啊呵呵呵呵呵呵')
# (0, '笨猪笨猪笨猪笨猪')
# (0, '救命救命救命救命')
# (0, '妈妈嘿嘿嘿嘿嘿嘿')
# (0, '嘿嘿嘿嘿嘿嘿打开')
# (0, '你漂亮的太漂亮了')
# (0, '你是不是脑子有病')
# (0, '我怎么这么好看')
# (0, '我不想跟你说了')
# (0, '啊哈哈哈哈哈哈')
# (0, '哈哈哈小朋友了')
# (0, '哈哈哈哈干什么')
# (0, '哈哈呵呵没事儿')
# (0, '号哼哼哼哼哼哼')
# (0, '你怎么那么笨蛋')
# (0, '你怎么这么聪明')
# (0, '你怎么这么好看')
# (0, '你大爷你别说话')
# (0, '你喜欢我哪一点')
# (0, '为何受伤的是我')
# (0, '高高兴兴回家')
# (0, '那你也太笨了')
# (0, '老子也不给我')
# (0, '神经病神经病')
# (0, '真的是无语了')
# (0, '男人喜欢喜欢')
# (0, '我超级喜欢你')
# (0, '我已经生气了')
# (0, '我不想见到你')
# (0, '奔驰你好可爱')
# (0, '回来了神经病')
# (0, '哼哼哼哼笑话')
# (0, '哎呀伤不起啊')
# (0, '哈哈哈哈启动')
# (0, '呵呵呵呵额额')
# (0, '听烦了听烦了')
# (0, '吓了一跳过去')
# (0, '你长得很漂亮')
# (0, '你长得太丑了')
# (0, '你神经病啊你')
# (0, '你真笨你真笨')
# (0, '你真的好笨啊')
# (0, '你真是太笨了')
# (0, '你是我最美的')
# (0, '你是啥玩意儿')
# (0, '你是什么玩意')
# (0, '你是不是有病')
# (0, '你怎么不听话')
# (0, '今天心情不好')
# (0, '陈静是垃圾')
# (0, '说个奶奶的')
# (0, '突然好想你')
# (0, '永远的微笑')
# (0, '比较喜欢你')
# (0, '曾经的心痛')
# (0, '是喜欢我的')
# (0, '文明你大爷')
# (0, '我靠靠这么')
# (0, '我讨厌你了')
# (0, '我的小可爱')
# (0, '我是喜欢你')
# (0, '我找个美女')
# (0, '我我喜欢你')
# (0, '我心情不爽')
# (0, '我喜欢黄色')
# (0, '我喜欢老虎')
# (0, '忽然好想你')
# (0, '小米别吵了')
# (0, '妈妈爱着你')
# (0, '太好了谢谢')
# (0, '嘿嘿黑多了')
# (0, '喜不喜欢我')
# (0, '哈哈哈哈啊')
# (0, '哈哈哈你好')
# (0, '哈哈你个头')
# (0, '呵呵你也好')
# (0, '吩咐你妹啊')
# (0, '可是我很烦')
# (0, '只是太爱你')
# (0, '受伤的女人')
# (0, '你长得真丑')
# (0, '你长得好丑')
# (0, '你那个垃圾')
# (0, '你这个笨猪')
# (0, '你这个疯子')
# (0, '你就是头猪')
# (0, '你妹喜欢我')
# (0, '你奶奶个蛋')
# (0, '你奶奶个头')
# (0, '你太漂亮了')
# (0, '你也很可爱')
# (0, '你也好漂亮')
# (0, '伤心的城市')
# (0, '不想搭理你')
# (0, '非常漂亮')
# (0, '非常好看')
# (0, '这个毛线')
# (0, '说你丫的')
# (0, '讨厌武侠')
# (0, '胡说八道')
# (0, '美女你好')
# (0, '真笨真坏')
# (0, '真的很痛')
# (0, '真的好烦')
# (0, '真心爱人')
# (0, '看见你烦')
# (0, '男孩别哭')
# (0, '猪猪猪猪')
# (0, '特别喜欢')
# (0, '爱人美丽')
# (0, '智障智障')
# (0, '无尽空虚')
# (0, '担惊受怕')
# (0, '我越喜欢')
# (0, '我赞你了')
# (0, '我要美女')
# (0, '我要生气')
# (0, '我的爱人')
# (0, '我是坏蛋')
# (0, '我好烦啊')
# (0, '我也很烦')
# (0, '我也喜欢')
# (0, '恐怖电影')
# (0, '开心开心')
# (0, '帅哥你好')
# (0, '对不起了')
# (0, '妈蛋回家')
# (0, '太漂亮了')
# (0, '大坏蛋的')
# (0, '哈哈拜拜')
# (0, '呵呵真的')
# (0, '呜呜呜呜')
# (0, '别人烦咯')
# (0, '你说话啊')
# (0, '你真的是')
# (0, '你是美女')
# (0, '你是畜生')
# (0, '你是瓜批')
# (0, '你是猪头')
# (0, '你是帅哥')
# (0, '你是小猪')
# (0, '你是坏人')
# (0, '你很漂亮')
# (0, '你好美女')
# (0, '你好笨蛋')
# (0, '你好烦哟')
# (0, '你好恶心')
# (0, '你好你妹')
# (0, '你太帅了')
# (0, '你大坏蛋')
# (0, '你喜欢你')
# (0, '你个头啊')
# (0, '伤心城市')
# (0, '亏欠一生')
# (0, '为情所伤')
# (0, '不吃垃圾')
# (0, '我爱你why')
# (0, '这么穷')
# (0, '赞赞赞')
# (0, '老疼了')
# (0, '笨蛋你')
# (0, '笨小孩')
# (0, '神经啊')
# (0, '神经了')
# (0, '真不错')
# (0, '痛苦啊')
# (0, '爱过我')
# (0, '烦人啊')
# (0, '没说你')
# (0, '救命啊')
# (0, '我靠行')
# (0, '我讨厌')
# (0, '我爱爱')
# (0, '我很烦')
# (0, '我头疼')
# (0, '我嘿嘿')
# (0, '我勒个')
# (0, '悲伤的')
# (0, '小混蛋')
# (0, '宝贝儿')
# (0, '失恋了')
# (0, '太脏了')
# (0, '太帅了')
# (0, '太吵了')
# (0, '垃圾了')
# (0, '喜欢了')
# (0, '哈巴狗')
# (0, '哈哈你')
# (0, '像你妹')
# (0, '你老妈')
# (0, '你缺德')
# (0, '你真菜')
# (0, '你有毒')
# (0, '你别吵')
# (0, '你也乖')
# (0, '伪君子')
# (0, '不吵了')
# (0, '心痛2009')
# (0, '伤心1999')
# (0, '耶耶')
# (0, '病鸡')
# (0, '狗蛋')
# (0, '犊子')
# (0, '爱人')
# (0, '烦躁')
# (0, '烦恼')
# (0, '扯淡')
# (0, '心烦')
# (0, '坏蛋')
# (0, '坏人')
# (0, '嘻哈')
# (0, '哭哭')
# (0, '吓人')
# (0, '不爽')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '我儿子很丑很丑很丑很丑，真的很丑')
# (0, '你百分之百哈哈哈哈哈哈哈哈哈哈哈')
# (0, '爸爸真的很丑很丑很丑很丑')
# (0, '大姐嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '呜呜呜呜呜呜呜呜呜呜呜呜')
# (0, '哼哼哼哼哼哼哼哼哼哼的')
# (0, '我现在心情不好怎么办')
# (0, '你是什么玩意儿机器人')
# (0, '你们喜欢一个哈尔小学')
# (0, '我爱你我爱你我爱你')
# (0, '我爱你了就是你妹妹')
# (0, '我是一个很乖的孩子')
# (0, '你喜欢男生还是女生')
# (0, '每天过得开开心心')
# (0, '我漂亮还是你漂亮')
# (0, '我是好人还是坏人')
# (0, '我喜欢我喜欢紫色')
# (0, '我亲爱亲爱的老婆')
# (0, '我也很高兴认识你')
# (0, '哈哈哈哈打开优盘')
# (0, '你是不是有病啊你')
# (0, '你怎么这么恶心啊')
# (0, '你怎么这么不听话')
# (0, '你太笨了你太笨了')
# (0, '你不是真正的快乐')
# (0, '中国的哈哈哈哈哈')
# (0, '一千个伤心的理由')
# (0, '神经病打开导航')
# (0, '我觉得你很漂亮')
# (0, '我生气了怎么办')
# (0, '我特别对不起你')
# (0, '小微你好厉害啊')
# (0, '封神封神我爱你')
# (0, '姑娘姑娘你真美')
# (0, '啊啊啊啊啊啊啊')
# (0, '哈哈是什么意思')
# (0, '呵呵哈哈哈哈哈')
# (0, '呵呵呵呵呵呵哈')
# (0, '你要是喜欢貂蝉')
# (0, '你是不是讨厌我')
# (0, '你是不是有病啊')
# (0, '你怎么那么蠢啊')
# (0, '你怎么这么可爱')
# (0, '你怎么不说话啊')
# (0, '你怎么不理我了')
# (0, '你怎么不听话了')
# (0, '你可爱嘛小笨蛋')
# (0, '你为什么不理我')
# (0, '一二三四喜欢你')
# (0, '长痛不如短痛')
# (0, '肚子痛怎么办')
# (0, '美女喜欢紫色')
# (0, '祝您一路顺风')
# (0, '我真的好孤单')
# (0, '我有点讨厌你')
# (0, '我承认我怕黑')
# (0, '我喜欢范晓萱')
# (0, '我喜欢的歌曲')
# (0, '我也很喜欢你')
# (0, '我也在想你啊')
# (0, '我也喜欢你呀')
# (0, '我一点也不好')
# (0, '对不起我爱你')
# (0, '宝贝宝贝宝贝')
# (0, '嘎嘎你恶心啊')
# (0, '哈哈老婆老婆')
# (0, '哈哈没有没有')
# (0, '哈哈你是个啥')
# (0, '呵呵呵呵干嘛')
# (0, '发烧了怎么办')
# (0, '加油亲如兄弟')
# (0, '你这个神经病')
# (0, '你这个大坏蛋')
# (0, '你脑子进水了')
# (0, '你真是太棒了')
# (0, '你是神经病啊')
# (0, '你是我的骄傲')
# (0, '你是不是智障')
# (0, '你好笨你好笨')
# (0, '你喜欢我什么')
# (0, '你今天就算了')
# (0, '你什么毛病啊')
# (0, '你不要说话了')
# (0, '但是我喜欢的')
# (0, '什么玩意儿啊')
# (0, '亲爱的亲爱的')
# (0, '为什么不理我')
# (0, '上班你好美女')
# (0, '你怎么哈哈seeyou啊')
# (0, '高兴认识你')
# (0, '闹够了没有')
# (0, '老子没喊你')
# (0, '第一个伤心')
# (0, '神经病啊你')
# (0, '疯狂爱爱爱')
# (0, '现在没钱了')
# (0, '我要你干嘛')
# (0, '我翻白眼了')
# (0, '我爸爸很丑')
# (0, '我爸帅不帅')
# (0, '我爱你福特')
# (0, '我有点孤独')
# (0, '我我我爱你')
# (0, '我喜欢这个')
# (0, '我喜欢粉色')
# (0, '我喜欢你了')
# (0, '我只在乎你')
# (0, '我也很开心')
# (0, '总有你鼓励')
# (0, '幸福两口子')
# (0, '就是喜欢你')
# (0, '小薇我爱你')
# (0, '小度我爱你')
# (0, '宝贝对不起')
# (0, '大哥别杀我')
# (0, '大哥你好乖')
# (0, '因为我爱你')
# (0, '嘿嘿我演示')
# (0, '喜欢的音乐')
# (0, '喜欢你咋办')
# (0, '啊你好给力')
# (0, '哈哈哈好好')
# (0, '哈哈哈哈你')
# (0, '哈哈哈再见')
# (0, '命里缺个你')
# (0, '呵呵没事了')
# (0, '呵呵哈哈哈')
# (0, '呵呵呵呵哈')
# (0, '听不懂算了')
# (0, '再也不是你')
# (0, '你长得很丑')
# (0, '你这么漂亮')
# (0, '你这个蠢货')
# (0, '你这个吊样')
# (0, '你是我孙子')
# (0, '你是小气鬼')
# (0, '你怎么回事')
# (0, '你就是坏人')
# (0, '你好神经病')
# (0, '你好小笨蛋')
# (0, '你好可爱啊')
# (0, '你先别说话')
# (0, '你你大爷的')
# (0, '伤心的路口')
# (0, '不要生气了')
# (0, '一点点喜欢')
# (0, '高高兴兴')
# (0, '闭嘴表示')
# (0, '野马好美')
# (0, '那怪烦人')
# (0, '那个笨蛋')
# (0, '逗我开心')
# (0, '退出笨蛋')
# (0, '这么恶心')
# (0, '这个讨厌')
# (0, '谢谢呵呵')
# (0, '谁理你了')
# (0, '讨厌鸭子')
# (0, '要么闭嘴')
# (0, '老子有理')
# (0, '美女帅哥')
# (0, '美女事儿')
# (0, '笨笨笨笨')
# (0, '神经病了')
# (0, '真的挺好')
# (0, '相爱一生')
# (0, '百年孤寂')
# (0, '甘心情愿')
# (0, '瑟瑟发抖')
# (0, '猪朋狗友')
# (0, '猪头猪头')
# (0, '特别新娘')
# (0, '爱为你好')
# (0, '没空理你')
# (0, '有病啊你')
# (0, '最美婚礼')
# (0, '无法原谅')
# (0, '找个美女')
# (0, '我要宝贝')
# (0, '我的妈呀')
# (0, '我的乖乖')
# (0, '我生气啊')
# (0, '我爱你啊')
# (0, '我求你了')
# (0, '我是哑巴')
# (0, '我想念你')
# (0, '我好开心')
# (0, '我失业了')
# (0, '我会喜欢')
# (0, '感谢你了')
# (0, '思念成伤')
# (0, '心烦易怒')
# (0, '开心老婆')
# (0, '开心宝贝')
# (0, '开开心心')
# (0, '宝贝老婆')
# (0, '宝贝拜拜')
# (0, '始乱终弃')
# (0, '好好恋爱')
# (0, '坏蛋坏蛋')
# (0, '四大美女')
# (0, '嘿嘿没有')
# (0, '嘿嘿嘻嘻')
# (0, '嘻嘻哈哈')
# (0, '喜欢小志')
# (0, '啥玩意儿')
# (0, '哭笑不得')
# (0, '哎呀讨厌')
# (0, '哎呀哈哈')
# (0, '哈哈那个')
# (0, '哈哈真的')
# (0, '哈哈打开')
# (0, '哈哈大笑')
# (0, '哈哈哈啊')
# (0, '吼吼吼吼')
# (0, '可爱动人')
# (0, '你神经啊')
# (0, '你的烦恼')
# (0, '你是疯子')
# (0, '你是爱情')
# (0, '你是混蛋')
# (0, '你弄错了')
# (0, '你完蛋了')
# (0, '你好脑残')
# (0, '你好美丽')
# (0, '你好烦呐')
# (0, '你好小笨')
# (0, '你好宝贝')
# (0, '你好垃圾')
# (0, '你好坏蛋')
# (0, '你好嘻嘻')
# (0, '你好可爱')
# (0, '你太棒了')
# (0, '你别逗我')
# (0, '你乖乖的')
# (0, '你不听话')
# (0, '伴娘好看')
# (0, '伤不起啊')
# (0, '亲亲我我')
# (0, '不要生气')
# (0, '不要乱叫')
# (0, '不用理他')
# (0, '不会说话')
# (0, '万恩千爱')
# (0, '麻烦啊')
# (0, '难过了')
# (0, '笨蛋蛋')
# (0, '的漂亮')
# (0, '疑心病')
# (0, '爱过你')
# (0, '爱贤道')
# (0, '爱着你')
# (0, '爱哭鬼')
# (0, '爱上你')
# (0, '爱上了')
# (0, '烦烦烦')
# (0, '漂亮啊')
# (0, '漂亮了')
# (0, '混蛋你')
# (0, '我靠靠')
# (0, '我牙疼')
# (0, '我心疼')
# (0, '我帅哥')
# (0, '我太笨')
# (0, '悲剧了')
# (0, '小气鬼')
# (0, '宝贝了')
# (0, '孤独了')
# (0, '好香啊')
# (0, '好美啊')
# (0, '太难了')
# (0, '太贱了')
# (0, '太萌了')
# (0, '太乖了')
# (0, '太丑了')
# (0, '大嘴巴')
# (0, '坑爹啊')
# (0, '哈哈笑')
# (0, '哈哈的')
# (0, '哈哈我')
# (0, '发烧了')
# (0, '你骂人')
# (0, '你真蠢')
# (0, '你真的')
# (0, '你漂亮')
# (0, '你母猪')
# (0, '你欠揍')
# (0, '你最帅')
# (0, '你扯淡')
# (0, '你吹牛')
# (0, '你可爱')
# (0, '你厉害')
# (0, '你出去')
# (0, '你乱说')
# (0, '你丫子')
# (0, '伤心嘛')
# (0, '乖乖啊')
# (0, '丑八怪')
# (0, '不鸟你')
# (0, '不玩了')
# (0, '你是sb')
# (0, '闹心')
# (0, '赞赞')
# (0, '老子')
# (0, '疼爱')
# (0, '煞笔')
# (0, '烦烦')
# (0, '我怕')
# (0, '心痛')
# (0, '帅气')
# (0, '寂寞')
# (0, '委屈')
# (0, '妈呀')
# (0, '好玩')
# (0, '好惨')
# (0, '嘿哟')
# (0, '厉害')
# (0, '八蛋')
# (0, '优美')
# (0, '不乖')
# (0, '2020伤感')
# (0, '123我爱你')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '哼哼哼哼哼哼哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '飞机哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴闭嘴')
# (0, '唉你就当我的水泥地不老什么都是亏你脑残了我也有点怎么弄啊')
# (0, '哈哈哈哈哈哈哈哈哈啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哼哼哼哼哼哼哼哼哼哼哼哼哈哈哈哈哈哈哈哈哈哈哈哈哈哼哼')
# (0, '哈哈呵呵哈哈呵呵哈哈呵呵哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '呵呵哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿哈哈哈哈哈哈哈哈')
# (0, '哼哼哼哼哼哼哼哼嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '不要呵呵呵呵呵呵呵呵呵呵暴走垃圾车还有也不是搞不清么')
# (0, '管他干吗一会儿要开一个你们太吵了他也听不见你们说啥')
# (0, '海云出来了已经出来了啊哈哈哈哈哈第一个哈哈哈知道了')
# (0, '斜塘派出所斜塘派出所你这个小呆萌你这个笨蛋小微你好')
# (0, '拜拜哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈我也不懂你说啥了哈')
# (0, '哈哈哈哈哈哈哼哼哼哼哼哼哼哼哼哼哼哼哼哼哼哼哼哼')
# (0, '哈哈哈哈哈哈哈哈呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '呵呵呵呵呵呵呵呵哈哈哈哈哈哈呵呵呵呵呵呵呵呵呵呵')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '还没复习我也没有我啥都没有我靠我就我就弄个手套')
# (0, '就是哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈好久不用了')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈笑哈哈')
# (0, '哈哈哈哈哈哈哈呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '呵呵哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哼哼哼哼哼哼唉我现在我了不煽动你了你也玩起了')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈长得比较抽象')
# (0, '哈哈哈哈哈哈哈哈呵呵呵呵呵呵呵呵哈哈哈哈哈哈')
# (0, '芭比更新妮妮妮哈哈哈哈哈哈哈哈哈哈哈哈嘿嘿')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿小度')
# (0, '啊哈哈我现在我饿我饿我在这个世界存在这个人')
# (0, '哈哈哈哈我等你你也发不过来算了拜拜弄上去了')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈的笑话了我再来一个')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈我要宠物店')
# (0, '哈哈你睡觉啊你休息你休息嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '呵呵呵呵呵呵呵呵哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '你晚上是不是睡觉了哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈82')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈我来点歌')
# (0, '哈哈哈哈哈哈呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '你是谁你还喝不喝啊没完了那放假了吗也不晚')
# (0, '人家才不上当哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '了才就发了就是那边的哈哈哈哈嘿嘿呵呵呵呵')
# (0, '不是哼哼哼哼哼哼哼哼哼哼哈哈哈哈哈哈哈哈')
# (0, '天猫京哈哈哈哈哈哈哈哈哈哈哈哈你好捷度')
# (0, '哈哈哈有人说我喜欢我我才会高兴呢嘿嘿嘿')
# (0, '呵呵呵呵哈哈哈哈哈哈哈哈哈哈音量说话了')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵没事儿')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵好开心')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵嘿嘿嘿')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵为了你')
# (0, '你爱说亲亲嘛应该整天呆在皇帝身边啊这个')
# (0, '算了呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '真厉害啊啊哈哈哈废话的也厉害了我也在')
# (0, '欺负一点也不想的想法嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '我才不一百我把账户也发来哈哈哈哈哈哈')
# (0, '我就不信他不理我算了我不我也不理他了')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿哼哼哼哼哼哼哼哼哼哼')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈小度小度小度')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈呵呵呵呵呵呵')
# (0, '哈哈哈哈呵呵呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '呵呵呵呵呵呵呵呵哈哈哈哈哈哈哼哼哼哼')
# (0, '你若化成风哎我现在没空啊我也好喜欢你')
# (0, '你个笨蛋你那姐姐你呢咋的你不给发了吗')
# (0, '他就答应的我都生气了哈哈哈哈哈哈哈哈')
# (0, '爸爸哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '拉拉哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '我说你骂不了的东西嘛该说嘛就行了吗')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿干什毛病啊嘿嘿嘿嘿')
# (0, '嘿嘿再给发六七我都完了发一来发过来')
# (0, '哪儿来的小桂子她妈呀嗯我也哈哈笑了')
# (0, '哈哈哈哈哈哈哈哈嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈怎么不理我')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈新年好')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哈哈呵呵呵呵呵呵呵呵哈哈哈哈哈哈哈')
# (0, '你个神经病啊他还给我神经病弄不弄的')
# (0, '他导航导的到我怎么怎么看一个搞的了')
# (0, '不想说你说你要骂你你那样唧唧歪歪的')
# (0, '那我也直接无语走了哈哈哈我去下载')
# (0, '而且又长得好看的你学的自己更好看')
# (0, '真再说爱你才说了一我也没有那么烦')
# (0, '电话不考核我就害怕我了然后的大姐')
# (0, '现在温度现在已经很少哈哈哈哈那个')
# (0, '湖北的那个女的很烦你给我骂的恋曲')
# (0, '河南老婆呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '我太高兴了你真是好好学习就好了哟')
# (0, '我为什么不理你刚才为什么不理我啊')
# (0, '哼哼哼哼哼哼哼哼哼哼哼哼讲个笑话')
# (0, '哈哈哈哈哈哈哈哈嘿嘿哈哈哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈讲个笑话')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈度度小度')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈呵呵呵呵')
# (0, '哈哈可以了可以了哈哈哈哈哈哈哈哈')
# (0, '呵呵呵呵呵呵呵呵哼哼哼哼哼哼哼哼')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵导航你好')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵嘿嘿嘿嘿')
# (0, '反正合适造反啊嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '十四岁哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '你高兴病好了的不然分手了想着老太')
# (0, '你这个笨蛋还问我说句话你也听不懂')
# (0, '你好猪头你好猪头你好猪头你好猪头')
# (0, '你别说话了儿子啊你别人倒来倒去了')
# (0, '你们那边哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '不错不错你还是挺聪明的你可以退出')
# (0, '马上啊哈哈哈哈申请导航重新导航')
# (0, '这样笑哈哈知道了笑一笑笑笑一个')
# (0, '讲个笑话哈哈哈哈哈哈哈哈哈哈哈')
# (0, '睾丸睾丸你妹啊一壶老酒请放播放')
# (0, '没事没事没事呵呵哈哈哈哈哈哈哈')
# (0, '我老婆喜欢听的歌是李圣杰的最近')
# (0, '我爱你爱着你，就像老鼠爱大米。')
# (0, '我只是好玩好好好好讨厌一点就是')
# (0, '快的那我也堵不了你那骂人的话都')
# (0, '太伤肺不值得罗不要生气了吗抱歉')
# (0, '天天穿哈哈哈哈哈哈哈哈哈哈哈哈')
# (0, '在我喜欢你我也喜欢这样跟我说话')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿哈哈哈')
# (0, '嘿嘿嘿呵呵呵呵呵呵呵呵呵呵答应')
# (0, '哦你也很棒啊也是你帮我也很棒哦')
# (0, '哈哈小猪哈哈哈哈哈哈哈哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈哈哈哈哈哈小度')
# (0, '哈哈哈哈哈哈哈呵呵呵呵呵呵呵呵')
# (0, '呵呵呵呵呵呵发给我早上起来呵呵')
# (0, '你太烦了你连话都没听说你还要说')
# (0, '麻烦解决了麻烦你别那么麻烦了')
# (0, '笨鸟先飞啥意思啊哈哈哈哈哈哈')
# (0, '空气挺好的呵呵呵空气是挺好的')
# (0, '的酒杯的哈哈哈哈哈哈小度小度')
# (0, '爸爸妈妈我好爱你啊我就在门口')
# (0, '我就喜欢你你是不是有神经病呀')
# (0, '我也不敢生你气都不敢弄这个了')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿哪有啊随便')
# (0, '嘛呢你是啥意思你居然是杀人犯')
# (0, '啥颜色的我又不想穿的我穿不着')
# (0, '哼哼哼哼哼哼哼哼哼哼哼哼老乡')
# (0, '哼哼哼哼哼哼哼哼哼哼呵呵呵呵')
# (0, '哈哈哈哈这是真的啊真的好烦啊')
# (0, '哈哈哈哈哈哈哈红色哗哗哗笑话')
# (0, '哈哈哈哈哈哈哈哈明天早上明天')
# (0, '哈哈哈哈哈哈哈哈怎么这么那个')
# (0, '哈哈哈哈哈哈哈哈嘿嘿嘿嘿嘿嘿')
# (0, '哈哈哈哈哈哈哈哈嘿嘿哈哈哈哈')
# (0, '哈哈哈哈哈哈哈哈呵呵呵呵呵呵')
# (0, '哈哈呵呵哈哈呵呵哈哈呵呵哈哈')
# (0, '呵呵呵呵呵呵呵呵嘿嘿嘿嘿嘿嘿')
# (0, '呵呵呵呵呵呵呵呵哈哈哈哈嘿嘿')
# (0, '呵呵呵呵呵呵呵呵哈哈哈哈哈哈')
# (0, '呵呵呵呵呵呵呵呵呵呵呵呵小度')
# (0, '呵呵你还是挺聪明的哈哈哈哈哈')
# (0, '吼吼吼吼哼哼哼哼哼哼哼哼哼哼')
# (0, '反正我也不骂你你我也不理你了')
# (0, '出来呵呵呵呵呵呵呵呵呵呵呵呵')
# (0, '几点下班啊嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '俺不是早就瞌睡呀我不跟你说话')
# (0, '你这么多问题都不会回答挺笨的')
# (0, '你这个笨蛋，你这个笨蛋笨蛋。')
# (0, '你再说这句话，我就打你的嘴了')
# (0, '伤心的时候伤心的话伤心的喜欢')
# (0, '马阳阳哈哈哈哈哈哈哈哈不用')
# (0, '逍遥哈哈哈哈哈哈哈哈哈哈哈')
# (0, '这是什么玩意儿啊什么玩意儿')
# (0, '这个好像不太行哈哈哈哈哈到')
# (0, '足球北京哈哈哈哈哈哈哈哈哈')
# (0, '没事了哈哈哈哈哈哈哈哈哈哈')
# (0, '是笨蛋笨蛋笨蛋笨蛋笨蛋笨蛋')
# (0, '我看你就烦你，不要跟我说话')
# (0, '我爱你爱着你就像老鼠爱大米')
# (0, '我想静静的喜欢你吗我就不行')
# (0, '我开车的技术呵呵呵呵哈哈哈')
# (0, '我就说你头脑有包你还不相信')
# (0, '我喜欢跑步滑冰跳绳跳远跳高')
# (0, '我喜欢红色你好奔驰你好奔驰')
# (0, '我喜欢你我喜欢你作者韩东旭')
# (0, '我不想说话你别理我不想理你')
# (0, '小流氓似的呵呵呵呵呵呵呵呵')
# (0, '孙小度度哈哈哈哈小度小兔子')
# (0, '因为你说你讨厌我我也讨厌你')
# (0, '嘿嘿嘿嘿嘿嘿哈哈哈哈哈哈哈')
# (0, '嗯你叫我自个去弄也不好听的')
# (0, '啊嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '哼哼哈哈哈哈哈我也有属性了')
# (0, '哎呀这个这个这个坑爹的家伙')
# (0, '哈哈哈哈哈我听到一个搞笑的')
# (0, '哈哈哈哈哈哈啊啊啊啊啊啊啊')
# (0, '哈哈哈哈哈哈哈哈哈我怕山河')
# (0, '哈哈哈哈哈哈哈你妹妹你美美')
# (0, '呵呵呵呵嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '呵呵呵呵哈哈哈哈哈哈哈哈哈')
# (0, '呵呵呵呵呵呵呵呵新年好应该')
# (0, '呵呵呵呵呵呵呵呵哈哈哈哈哈')
# (0, '呵呵呵呵呵呵呵呵呵呵嘿嘿嘿')
# (0, '你还挺聪明的啊求生欲挺强啊')
# (0, '你烦不烦我你自己也不愿意啊')
# (0, '你挺聪明的嘛，清智能的吗？')
# (0, '你大爷你大爷的你你你你你啊')
# (0, '你喜欢跆拳道完事喜欢打篮球')
# (0, '你你走吧不需要你了你好烦哦')
# (0, '你不要再烦了就这样下也没事')
# (0, '你不是哈哈哈哈哈哈哈哈哈哈')
# (0, '人家的小笨蛋也不是太笨了呢')
# (0, '也不敢飞寂寞沙洲我该思念谁')
# (0, '为什么不关我什么都越说越烦')
# (0, '麻痹麻痹麻痹麻痹麻痹麻痹')
# (0, '饿饿饿饿饿饿饿不饿气你呀')
# (0, '那你说你说让我穿你那垃圾')
# (0, '这个名字就重名了嘛哈哈哈')
# (0, '豆角豆角哈哈哈哈哈哈哈哈')
# (0, '老公老公哈哈哈哈哈哈哈哈')
# (0, '笑嘻嘻谁谁谁什么谁谁谁的')
# (0, '爸爸巴士我叫涛涛嘿嘿嘿嘿')
# (0, '烧饼怎么弄哈哈哈哈哈哈哈')
# (0, '没什么人烦我了了小度小度')
# (0, '没事没事呵呵呵呵呵呵呵呵')
# (0, '是不是啊是不是真的喜欢我')
# (0, '提醒我了啊呵呵哈哈哈哈哈')
# (0, '挺喜欢你聊不来的啊哈哈哈')
# (0, '我觉得你就是头猪啥也不会')
# (0, '我害怕海王你挺啥都那个档')
# (0, '我受委屈了你这个第三批了')
# (0, '微微你不要说话好了你好烦')
# (0, '小乔姑娘哈哈哈哈哈哈哈哈')
# (0, '嘿嘿醒了就给你的那个小米')
# (0, '嘿嘿嘿嘿嘿嘿哈哈哈哈哈哈')
# (0, '嘿嘿嘿嘿嘿嘿呵呵呵呵呵呵')
# (0, '嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻')
# (0, '啊啊知道了哈哈哈哈哈哈哈')
# (0, '啊哈哈我还有你们那些学校')
# (0, '哎呀我勒个老婆子你怎么说')
# (0, '哎呀啥烦你意思了你要开会')
# (0, '哈哈哈哈的的后面哪有时间')
# (0, '哈哈哈哈哈哈微信咋学不会')
# (0, '哈哈哈哈哈哈哈哈哈简单的')
# (0, '哈哈哈哈哈哈哈哈哈哈哈你')
# (0, '哈哈哈哈哈哈哈哈什么什么')
# (0, '哈哈哈哈哈哈哈你别这样了')
# (0, '哈哈哈哈呵呵呵呵呵呵呵呵')
# (0, '呵呵呵呵嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '呵呵呵呵嘿嘿嘿嘿哼哼哼哼')
# (0, '呵呵呵呵哈哈哈哈呵呵呵呵')
# (0, '呵呵呵呵呵呵哼哼哼哼哼哼')
# (0, '呵呵呵呵呵呵呵呵龙湖天街')
# (0, '呵呵呵呵呵呵呵呵嘿嘿嘿嘿')
# (0, '呵呵呵呵他又听到我说的了')
# (0, '吃了我的心不如要了我的命')
# (0, '俺之前才穿的回去挺恶心啊')
# (0, '你这样跟我说话我很不开心')
# (0, '你这个婆娘你竟然撤破别人')
# (0, '你说你刚才说哈哈哈哈哈哈')
# (0, '你是一个小笨蛋小丫小笨蛋')
# (0, '你怎么这么笨象周小穷一样')
# (0, '你好哈哈哈哈哈哈哈哈嘿嘿')
# (0, '你以为谁都像你这么爽啊。')
# (0, '不说了，就感觉你好烦啊。')
# (0, '神经病的医生开始说话了1块钱')
# (0, '这个图片我刚看到嘿嘿嘿')
# (0, '费劲啊你脑子听不懂啊你')
# (0, '真的生气了生气了不气了')
# (0, '看着这些这些恶心的家伙')
# (0, '泸州嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '是的管不了啊哈哈哈哈哈')
# (0, '我跟你说话你怎么不听呢')
# (0, '我说喜欢我谁老子疯了走')
# (0, '我的性格比较喜欢你大人')
# (0, '我生气了就多一份安全感')
# (0, '我是可爱的可爱的小可爱')
# (0, '我我你你好小气你好小气')
# (0, '我好开心因为明天联欢会')
# (0, '我喜欢你，我喜欢你第号')
# (0, '我哈子哈哈哈我哈哈哈哈')
# (0, '就聊那个你说的啥意思嘛')
# (0, '就像你吼就像泥巴一样的')
# (0, '对呀我也觉得我挺漂亮的')
# (0, '嘿嘿有空也去你们那儿玩')
# (0, '嘿嘿嘿嘿嘿嘿打开播放的')
# (0, '嘿嘿嘿嘿嘿嘿嘿小度小度')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿怎么弄')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿哈哈')
# (0, '喜欢看嘛电影回给我电话')
# (0, '喜欢的是你满意了怎么办')
# (0, '啊啊啊啊啊啊啊啊啊哈哈')
# (0, '啊啊啊啊啊哈哈哈哈哈哈')
# (0, '啊哈哈哈哈啊啊啊啊啊啊')
# (0, '哼哼嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '哼哼哼哼哼哼我新年快乐')
# (0, '哼哼哼哼哈哈哈哈哈哈哈')
# (0, '哼哼你好像没有说话的了')
# (0, '哈哈好看嘛好看嘛照好面')
# (0, '哈哈哈江南江南江南就是')
# (0, '哈哈哈我是卖报的小新家')
# (0, '哈哈哈哈，是什么意思？')
# (0, '哈哈哈哈哈哈啊哈哈哈哈')
# (0, '哈哈哈哈哈哈哈没事拜拜')
# (0, '哈哈哈哈哈哈哈哈第一个')
# (0, '哈哈哈哈哈哈哈哈好好笑')
# (0, '哈哈哈哈哈哈哈哈哈哈。')
# (0, '哈哈哈哈哈哈你文科是啊')
# (0, '呵呵嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '呵呵呵呵哈哈哈哈哈害羞')
# (0, '呵呵呵呵呵呵呵呵哈哈哈')
# (0, '叮咚你好漂亮你好漂亮啊')
# (0, '别人骂你的发现了你好鸟')
# (0, '再说一次说了你又听不懂')
# (0, '俺奶奶我还拖着嘿嘿嘿嘿')
# (0, '你高兴个头啊哎呀没事啊')
# (0, '你觉得恶缘淅川帅不帅？')
# (0, '你行不行哈哈哈哈哈哈哈')
# (0, '你是我心中最爱的女孩儿')
# (0, '你是不是脑子有点瓦特了')
# (0, '你是一个坏孩子我告诉你')
# (0, '你拉个巴子昨天晚上才睡')
# (0, '你怕不怕那种恐怖的游戏')
# (0, '你就是个废物啥也干不了')
# (0, '你大爷的你什么时候回来')
# (0, '你喜欢爸爸还是喜欢妈妈')
# (0, '你喜欢我带你去干什么？')
# (0, '你喜不喜欢你喜不喜欢我')
# (0, '你不会努力的你太笨了你')
# (0, '但是我不太喜欢那种东西')
# (0, '什么地方了嘿嘿嘿嘿嘿嘿')
# (0, '人工智障智障你这个智障')
# (0, '亚丝惊讶哈哈哈哈哈哈哈')
# (0, '买房退出不要吓唬我东西')
# (0, '为什么呵呵呵呵呵呵呵呵')
# (0, '为为什么不说话啊说话嘛')
# (0, '不跟你扯淡了我在中国了')
# (0, '晚安宝贝宝贝老婆大人666')
# (0, '黑个司机跟着我哈哈哈')
# (0, '那这下像了你看着漂亮')
# (0, '那些高血压呵呵搞笑的')
# (0, '这样的话就是故障的话')
# (0, '这么磨叽啊你好墨迹啊')
# (0, '这个干球啥的我生气了')
# (0, '还有老人家别说啥你说')
# (0, '谢谢你了谢谢你的夸奖')
# (0, '讨厌讨厌讨厌讨厌讨厌')
# (0, '蝴蝶原来讨厌讨厌蝴蝶')
# (0, '老婆你老打击我们作业')
# (0, '老娘们儿不听话怎么弄')
# (0, '继续点盟嘿嘿嘿嘿嘿嘿')
# (0, '结果妈妈生气了怎么办')
# (0, '笨鸟先飞是不是刘宁飞')
# (0, '笑话哈哈哈笑话哈哈哈')
# (0, '琪琪我爱你是什么意思')
# (0, '爱你无惊无命不知惊吧')
# (0, '滴滴滴滴滴滴滴滴什么')
# (0, '我相信不过一样的哈哈')
# (0, '我爱你我爱你别人打字')
# (0, '我没有女朋友嘿嘿嘿嘿')
# (0, '我感觉你不太想理我。')
# (0, '我就是喜欢这个恐怕你')
# (0, '我媳妇儿生气了怎么办')
# (0, '我喜欢绿色蓝色的瓶子')
# (0, '我喜欢前面那个小女孩')
# (0, '我也喜欢你怎样喜欢啊')
# (0, '我也喜欢你开心的表情')
# (0, '我为什么这么讨厌歌曲')
# (0, '干嘛我们吵架你干嘛？')
# (0, '帮主嘿嘿嘿嘿嘿嘿嘿嘿')
# (0, '小度你太坏了不理你了')
# (0, '小度不想理你嘛行不行')
# (0, '好想你一首歌心想事成')
# (0, '天天嘎嘎嘎嘎嘿嘿嘿嘿')
# (0, '嘿嘿嘿嘿嘿嘿超级时刻')
# (0, '嘿嘿嘿嘿嘿嘿演讲回来')
# (0, '嘿嘿嘿嘿嘿嘿嘿嘿嘿啊')
# (0, '嘿嘿嘿嘿嘿嘿呵呵呵呵')
# (0, '嘿嘿嘿嘿哈哈哈哈哈哈')
# (0, '嘿嘿嘿你了谢谢你了是')
# (0, '嘿嘿嘿一定知道了老公')
# (0, '嘿嘿呵呵找到目的地了')
# (0, '啊胆子放大放大好不好')
# (0, '啊哈啊哈啊哈哈哈哈哈')
# (0, '啊哈哈啊哈啊哈啊哈啊')
# (0, '哼哼哼哼哼哼哼哼哎呀')
# (0, '哼哼哼哼哈哈哈哈哈哈')
# (0, '哈哈我妈也是小小个的')
# (0, '哈哈哈闭上你的乌鸦嘴')
# (0, '哈哈哈这么早就喝上了')
# (0, '哈哈哈我就是不想知道')
# (0, '哈哈哈哈要说一个笑话')
# (0, '哈哈哈哈我昨晚怎么了')
# (0, '哈哈哈哈就是这波错哈')
# (0, '哈哈哈哈嘿嘿我知道了')
# (0, '哈哈哈哈嘿嘿哈哈哈哈')
# (0, '哈哈哈哈哈哈现在你好')
# (0, '哈哈哈哈哈哈小度小度')
# (0, '哈哈哈哈哈哈哈哈迪厅')
# (0, '哈哈哈哈哈哈哈哈回家')
# (0, '哈哈哈哈哈哈哈哈嘿嘿')
# (0, '哈哈哈哈哈哈哈哈哼哼')
# (0, '哈哈哈哈哈哈哈哈再见')
# (0, '哈哈哈哈哈哈你好哈弗')
# (0, '哈哈哈你哈哈哈哈哈哈')
# (0, '呵呵呵呵铠甲勇士勇士')
# (0, '呵呵呵呵呵呵真的可以')
# (0, '呵呵呵呵呵呵哈哈哈哈')
# (0, '呵呵呵呵呵呵呵呵打开')
# (0, '可是可爱的可萌是萌萌')
# (0, '别跟我说话了我生气了')
# (0, '别扯那些亏不亏的道理')
# (0, '俺不能去了哈哈哈哈哈')
# (0, '你那个乱七八糟为什么')
# (0, '你这么聪明一定可以的')
# (0, '你这个坏蛋你这个坏蛋')
# (0, '你这个丑八怪全身不要')
# (0, '你笨蛋明天天气怎么样')
# (0, '你真的喜欢全都进去了')
# (0, '你的智商好差今天我差')
# (0, '你现在是越来越聪明了')
# (0, '你是笨蛋，你是笨蛋。')
# (0, '你是不是神经病是不是')
# (0, '你怎么现在反应太慢了')
# (0, '你好像一个笨猪一样的')
# (0, '你太笨了你是一个笨蛋')
# (0, '你什么东西什么东西啊')
# (0, '你也一点都不好玩为啥')
# (0, '你为什么不理我悠悠啊')
# (0, '你不喜欢我也不喜欢他')
# (0, '你不会待会儿哼哼哼哼')
# (0, '从我也喜欢你呀你爱我')
# (0, '不是那个贱人肯定不够')
# (0, '骂人是一种什么行为')
# (0, '靠你不为我着想了吗')
# (0, '青春女行嘿嘿嘿嘿嘿')
# (0, '陈瑞的胎儿炮台不行')
# (0, '闭嘴我知道你长什么')
# (0, '错过了缘分错过了你')
# (0, '讲话呵呵呵呵听不懂')
# (0, '讲个超级好笑的笑话')
# (0, '讲个笑话哈哈哈哈哈')
# (0, '讨厌讨厌你好讨厌。')
# (0, '老别别别哈哈哈哈哈')
# (0, '老公生气了怎么办？')
# (0, '现在都不开心的话了')
# (0, '猪猪啊猪头猪猪猪猪')
# (0, '爱我你就抱抱我啊。')
# (0, '烦不烦嘛银河奥特曼')
# (0, '没话说啊，腰痛啊。')
# (0, '沈阳哈哈哈哈哈哈哈')
# (0, '比较喜欢的一个部分')
# (0, '欢迎你的地方是天堂')
# (0, '木马木马是你不要脸')
# (0, '是一个小笨蛋小笨蛋')
# (0, '我这边真的讨厌之类')
# (0, '我说你长得好漂亮啊')
# (0, '我说了你不会弄我靠')
# (0, '我讨厌哈六什么照片')
# (0, '我生气了我我不是你')
# (0, '我生气了你逗我干嘛')
# (0, '我比较烦烦恼怎么办')
# (0, '我有点寂寞怎么办？')
# (0, '我最近挺烦的怎么办')
# (0, '我是不敢说走了就是')
# (0, '我才不是你的好朋友')
# (0, '我感觉你像娘们儿了')
# (0, '我心情不好开始吵架')
# (0, '我很烦很烦很烦很烦')
# (0, '我妈漂亮还是我爸帅')
# (0, '我妈妈麻烦麻烦麻烦')
# (0, '我喜欢孙雅莉的声音')
# (0, '我喜欢你，我喜欢你')
# (0, '我呵呵呵呵呵呵呵呵')
# (0, '我也很高兴见到你啊')
# (0, '我不理你了你好给力')
# (0, '感谢所有深爱的朋友')
# (0, '快点快点快点哈哈哈')
# (0, '弄你不赶快搞什么嘛')
# (0, '干什么不要说话了？')
# (0, '小猪哈哈哈哈哈哈哈')
# (0, '小子我的爱好是什么')
# (0, '宝贝交通呵呵呵呵啊')
# (0, '守护星开下门哈哈哈')
# (0, '媳妇儿生气了怎么办')
# (0, '好吃的哈哈哈哈哈哈')
# (0, '女朋友生气了怎么办')
# (0, '太给力了啊啊啊啊啊')
# (0, '夕阳红呵呵呵呵呵珍')
# (0, '增大压强喜欢漂亮的')
# (0, '嘿嘿朋友聊天就算了')
# (0, '嘿嘿嘿那个那个那个')
# (0, '嘿嘿嘿嘿机器人妈妈')
# (0, '嘿嘿嘿嘿嘿嘿嘿没有')
# (0, '嘿嘿嘿嘿嘿嘿嘿姐姐')
# (0, '嘿嘿嘿嘿嘿嘿哈哈哈')
# (0, '嘿嘿嘿嘿嘿嘿你减肥')
# (0, '嘿嘿嘿嘿嘿呵呵是的')
# (0, '喜欢聊天是我的爸爸')
# (0, '喜欢你，我喜欢你。')
# (0, '啊哈哈哈哈哈大坏蛋')
# (0, '啊你真的是很烦很烦')
# (0, '哼哼哼哼有没有行车')
# (0, '哼哼哼哼哼哼维多利')
# (0, '哎呀错了嘛你大爷的')
# (0, '哎呀我不要你了哼哼')
# (0, '哎你说脏话要干嘛我')
# (0, '哈哈啥子啥子啥子啊')
# (0, '哈哈哈我现在过来啊')
# (0, '哈哈哈哈过来了拜拜')
# (0, '哈哈哈哈路灯行不起')
# (0, '哈哈哈哈哪个帅哥啊')
# (0, '哈哈哈哈哈男生头像')
# (0, '哈哈哈哈哈哈我笑笑')
# (0, '哈哈哈哈哈哈哈哈。')
# (0, '哈哈哈哈哈哈哈呵呵')
# (0, '哈哈哈哈哈哈哈不用')
# (0, '哈哈哈再见哈哈哈哈')
# (0, '哈哈原来你也不认识')
# (0, '哈哈不行歌曲大沙河')
# (0, '呵呵呵呵早就睡觉了')
# (0, '呵呵呵呵呵呵呵呵。')
# (0, '呜呜呜爱尔眼科医院')
# (0, '你高兴嘿嘿嘿嘿嘿嘿')
# (0, '你这个不听话的东西')
# (0, '你走开我已经生气了')
# (0, '你解决不了我的问题')
# (0, '你脑子是不是锈了？')
# (0, '你真是讨人厌，真烦')
# (0, '你的智商太有问题了')
# (0, '你烦不烦你了聊天了')
# (0, '你没事干机会怀疑我')
# (0, '你是女生还是丑八怪')
# (0, '你是大坏蛋你不理俺')
# (0, '你是不是脑子瓦特了')
# (0, '你是不是脑子有病？')
# (0, '你是不是脑子有病啊')
# (0, '你是不是脑子坏掉了')
# (0, '你是不是是人工智障')
# (0, '你是不是嫌弃我笨蛋')
# (0, '你是不是听不懂仁化')
# (0, '你是不是人工智障？')
# (0, '你是一个聪明的小孩')
# (0, '你怎么那么不聪明呢')
# (0, '你怎么这么不耐烦啊')
# (0, '你怎么舍不得我难过')
# (0, '你干嘛偷听我们说话')
# (0, '你就是一个大坏蛋。')
# (0, '你好笨你好笨啊那个')
# (0, '你好哈哈哈哈哈哈我')
# (0, '你好听你唱歌吓一跳')
# (0, '你好你很漂亮我觉得')
# (0, '你太坏了我不要你了')
# (0, '你喜欢哪个动画人物')
# (0, '你喜欢吉利还是大白')
# (0, '你喜不喜欢你的主人')
# (0, '你别跟我说话我生气')
# (0, '你们不要说话好不好')
# (0, '你今晚走了也不吭气')
# (0, '你什么你你喜欢什么')
# (0, '你也挺好的挺好看的')
# (0, '你为什么解答不了？')
# (0, '你为什么刚才不理我')
# (0, '你不要你不要说话了')
# (0, '二哥也不说啥恶心啊')
# (0, '主人心情不好怎么办')
# (0, '不许笑呵呵哈哈呵呵')
# (0, '不累的啊哈哈哈哈哈')
# (0, '不玩了，老子不玩啊')
# (0, '不好意思嘻嘻谢谢你')
# (0, '下雨了呵呵呵呵呵呵')
# (0, '也喜欢他出道的嘛169块')
# (0, '靠靠靠靠靠靠靠靠')
# (0, '酸菜嘿嘿嘿嘿退出')
# (0, '那你说啥才听得见')
# (0, '那你也太笨了吧。')
# (0, '那你为什么不聪明')
# (0, '那伤的白色最好是')
# (0, '这么漂亮俺兜兜里')
# (0, '这个问题太高兴了')
# (0, '这个脑残这么简单')
# (0, '这个美女美不美啊')
# (0, '这个是悲伤的话题')
# (0, '谢谢了哈哈哈哈哈')
# (0, '请问你喜欢什么？')
# (0, '请大笨猪爸爸爸爸')
# (0, '说话你不要打岔了')
# (0, '记住了我会伤心的')
# (0, '讨厌讨厌讨厌讨厌')
# (0, '行不行嘛说这种唉')
# (0, '脑残你脑残的意思')
# (0, '肯定也喜欢玩同学')
# (0, '耶耶耶耶耶耶关掉')
# (0, '老子不说脏话不行')
# (0, '老公你真的太棒了')
# (0, '答案就是你是笨蛋')
# (0, '笨蛋的前天没活了')
# (0, '笨蛋你是一个笨蛋')
# (0, '笨笨笨笨笨笨笨笨')
# (0, '真的是一个笨哇路')
# (0, '生气生气生气生气')
# (0, '现在不敢出去了。')
# (0, '猪狗不如猪狗不如')
# (0, '特别的最后的机会')
# (0, '爱过了，也伤过了')
# (0, '然后我就很痛苦号')
# (0, '漂亮的跑车进去啊')
# (0, '漂亮是美丽的升华')
# (0, '比如说你喜欢什么')
# (0, '每次看到我喜欢的')
# (0, '杜序是不是大坏蛋')
# (0, '李雪哈哈哈哈什么')
# (0, '有点废话我下车。')
# (0, '是因为寂寞才想你')
# (0, '明天我喜欢听的歌')
# (0, '无聊你真是吵嘛了')
# (0, '无奈听不懂的公园')
# (0, '新年快乐新年快乐')
# (0, '放歌呵呵呵呵呵呵')
# (0, '我马上就要生气了')
# (0, '我靠不知道有油号')
# (0, '我难过就别伤害我')
# (0, '我说话你听不见了')
# (0, '我要呵呵呵呵呵呵')
# (0, '我自己腰疼怎么办')
# (0, '我真的多大了呵呵')
# (0, '我的宝贝女儿电话')
# (0, '我的伤悲不曾体会')
# (0, '我爱你真心真意的')
# (0, '我服了都是说好的')
# (0, '我有我有事欠抽啊')
# (0, '我感觉你大爷有病')
# (0, '我怎么这么喜欢你')
# (0, '我心情不好怎么办')
# (0, '我开心我天天开心')
# (0, '我帅我帅我帅我帅')
# (0, '我就生气了安哥儿')
# (0, '我姐姐亲爱的姐姐')
# (0, '我妹妹妹夫吵架的')
# (0, '我好帅，我好帅。')
# (0, '我喜欢我喜欢赛车')
# (0, '我喜欢大陆歌曲。')
# (0, '我喜欢吃零食咋办')
# (0, '我喜欢你我喜欢你')
# (0, '我喜欢一个美女。')
# (0, '我喜欢一个吴梦阳')
# (0, '我可是我怕老虎的')
# (0, '我到底做错了什么')
# (0, '我们闺蜜呵呵呵呵')
# (0, '我们来亲一口嘴巴')
# (0, '我也说我也爱你啊')
# (0, '我也烦我也烦这样')
# (0, '我也喜欢听你说话')
# (0, '我也喜欢你亲爱的')
# (0, '我不要你这个朋友')
# (0, '我不管你就是王八')
# (0, '我不想听见你说话')
# (0, '我不想今生失去。')
# (0, '我不喜欢虚拟的你')
# (0, '我不会的你别管我')
# (0, '感谢你曾经来过。')
# (0, '恭喜发财红包拿来')
# (0, '快点我不想看到你')
# (0, '快点一次痛多一次')
# (0, '心情很烦的发错了')
# (0, '心情不好夸夸我啊')
# (0, '心情不好了怎么办')
# (0, '开啦开喽开回来啊')
# (0, '尽说些不要脸的话')
# (0, '尼勒克的天气预报')
# (0, '小薇你心智太差了')
# (0, '小薇你不要说话了')
# (0, '小明你干得怎么样')
# (0, '小心别烦我啊这个')
# (0, '小度说也不想理你')
# (0, '小度我非常喜欢你')
# (0, '对不起我不能答应')
# (0, '妹妹生气了怎么办')
# (0, '妹妹不听话怎么办')
# (0, '妈妈特别对不起我')
# (0, '如果我喜欢的歌曲')
# (0, '如果喜欢你就行了')
# (0, '垃圾管理个啥呀还')
# (0, '因为我儿子喜欢我')
# (0, '嘿嘿嘿嘿嘿嘿海雅')
# (0, '嘿嘿嘿嘿嘿嘿哈哈')
# (0, '嘿嘿嘿嘿你敢说话')
# (0, '嘿嘿嘿嘿你好哈弗')
# (0, '嘿嘿嘿嘿你好你好')
# (0, '嘿嘿嘿哈哈哈好烦')
# (0, '嘿嘿嘿做多勒坐坐')
# (0, '嘿嘿嘻嘿嘻嘻嘻嘻')
# (0, '嘿嘿变压回头哈哈')
# (0, '嘿嘿你肯定你好看')
# (0, '嘻嘻嘻嘻嘻嘻嘻嘻')
# (0, '嘻嘻嘻嘻嘻嘻乖乖')
# (0, '喜爱看看你家灯光')
# (0, '啊啊啊啊啊哈哈哈')
# (0, '哼哼哼哼请放朋友')
# (0, '哼哼哼哼天气音乐')
# (0, '哪个你好喜欢你好')
# (0, '哥哥嘿嘿嘿嘿嘿嘿')
# (0, '哎呀妈呀我的妈呀')
# (0, '哎呀哎呀你真笨啊')
# (0, '哎呀别逗了嘿嘿嘿')
# (0, '哎呀你不要吵了嘛')
# (0, '哈哈终于超过我了')
# (0, '哈哈就这玩意儿了')
# (0, '哈哈小四小四连号')
# (0, '哈哈哈哈拜拜再见')
# (0, '哈哈哈哈小度小度')
# (0, '哈哈哈哈夜夜夜夜')
# (0, '哈哈哈哈嘿嘿呵呵')
# (0, '哈哈哈哈哈哈漂亮')
# (0, '哈哈哈哈哈哈哈。')
# (0, '哈哈哈哈哈哈五个')
# (0, '哈哈哈哈你是不是')
# (0, '哈哈哈你一样一样')
# (0, '哈哈哈今天聊天了')
# (0, '哈哈你大爷你大爷')
# (0, '哈哈你个头啊哈哈')
# (0, '咱俩是友谊长存的')
# (0, '呵呵谢谢我也想你')
# (0, '呵呵没有那么智能')
# (0, '呵呵嘿嘿放大风吹')
# (0, '呵呵哈哈哈我看行')
# (0, '呵呵呵呵小度小度')
# (0, '呵呵呵呵呵呵没事')
# (0, '呵呵呵呵呵呵哼哼')
# (0, '呵呵不要这样推理')
# (0, '呵呵不会的应该是')
# (0, '呜呜呜呜呜呜那个')
# (0, '吼吼吼吼吼吼哈嘿')
# (0, '吃饭老婆心烦移动')
# (0, '可可厉害的牧羊人')
# (0, '可不可以不要烦我')
# (0, '变量是啥意思呵呵')
# (0, '发的怎么这么烦啊')
# (0, '十大元帅介绍一下')
# (0, '十全十美十全十美')
# (0, '副驾驶的伟帅不帅')
# (0, '别吵知道了知道了')
# (0, '再见再见再也不见')
# (0, '再累我不想看见你')
# (0, '儿子喜欢我怎么办')
# (0, '你这样说太伤我了')
# (0, '你这个智能太差了')
# (0, '你这个小人好不好')
# (0, '你这个反应很慢啊')
# (0, '你自己哈哈你哈哈')
# (0, '你脑壳是不是有包')
# (0, '你能个毛线啊干嘛')
# (0, '你耳聋啊你耳背啊')
# (0, '你老汉就行了不管')
# (0, '你答应的这么吵吵')
# (0, '你真是一个大坏蛋')
# (0, '你看见了你是笨蛋')
# (0, '你的英语真的很差')
# (0, '你的脑瓜子不太好')
# (0, '你是说你是笨蛋吗')
# (0, '你是美女还是帅哥')
# (0, '你是笨蛋就是笨蛋')
# (0, '你是笨蛋你是笨蛋')
# (0, '你是王八还是乌龟')
# (0, '你是洗洗车也坏了')
# (0, '你是我最好的朋友')
# (0, '你是我今生的依靠')
# (0, '你是大笨蛋我饿了')
# (0, '你是什么玩意儿啊')
# (0, '你是什么你是猪叫')
# (0, '你是不是脑残啊你')
# (0, '你是不是个瓜娃子')
# (0, '你是不是不爱我了')
# (0, '你是不是一个智障')
# (0, '你扯淡谁不文明了')
# (0, '你怎么这么好看？')
# (0, '你怎么不会这样啊')
# (0, '你干嘛啊你说什么')
# (0, '你干嘛不理我哼哼')
# (0, '你就是这么恶心。')
# (0, '你就是我的大美女')
# (0, '你就是一个小笨蛋')
# (0, '你妹啊还是你家的')
# (0, '你妹别人我要妹妹')
# (0, '你妹你没面子思路')
# (0, '你好笨你好笨你好')
# (0, '你好哈弗你好哈弗')
# (0, '你好可爱可亲哪吒')
# (0, '你好你好呵呵呵呵')
# (0, '你太笨了这里没有')
# (0, '你在我心中是最美')
# (0, '你喜欢有点问题啊')
# (0, '你喜欢什么样的嘛')
# (0, '你哈哈准备炒菜啊')
# (0, '你哈哈你们告诉你')
# (0, '你可知心痛的滋味')
# (0, '你叫啥都也回应啊')
# (0, '你发神经呵呵呵呵')
# (0, '你别说话自作多情')
# (0, '你别说话小度小度')
# (0, '你你你你骚不骚啊')
# (0, '你们就弄得我车上')
# (0, '你以为我会谁错了')
# (0, '你什么也帮不了我')
# (0, '你为什么这么猥琐')
# (0, '你为什么回答不上')
# (0, '你不配我的眼泪。')
# (0, '你不配我流的眼泪')
# (0, '你不要说话好不好')
# (0, '你不要烦我很多人')
# (0, '你不要再烦我了。')
# (0, '你不能笑子新人啊')
# (0, '伤心的时候可以。')
# (0, '他就不管了上哪管')
# (0, '什么鸟毛我的号码')
# (0, '什么坏事我不加你')
# (0, '什么回事嘿嘿嘿嘿')
# (0, '乐乐乐乐乐乐乐乐')
# (0, '不用说了真是导航')
# (0, '不理你了不理你了')
# (0, '不是我的俺不要俺')
# (0, '不想说话我要说话')
# (0, '不想说话不想说话')
# (0, '不想回答你的问题')
# (0, '上句你毛病不要你')
# (0, '一会啊哈哈哈哈哈')
# (0, '一个人也挺好挺好')
# (0, '你的智商是不是250')
# (0, '呵呵今天就有了100块钱去')
# (0, '麻烦最多啊哈哈')
# (0, '高高兴兴这样啊')
# (0, '颜色你这个笨蛋')
# (0, '非常痛会少一点')
# (0, '闭上你的嘴巴。')
# (0, '酸辣粉哼哼哼哼')
# (0, '那就不想理你了')
# (0, '那你想撵他们吗')
# (0, '那你也太笨了吧')
# (0, '那也是很漂亮啦')
# (0, '这是嘿嘿嘿嘿嘿')
# (0, '这些歌太难听了')
# (0, '这个是什么你啊')
# (0, '这个伴娘真是的')
# (0, '赵芳菊喜欢你。')
# (0, '赞好再见你个头')
# (0, '说了你也听不懂')
# (0, '让你闭嘴蛋蛋蛋')
# (0, '见鬼了哈哈哈哈')
# (0, '要不说你神经病')
# (0, '蔡明是大坏蛋啊')
# (0, '耶耶耶耶耶耶耶')
# (0, '老虎汤也怕呛啊')
# (0, '老子就是生气了')
# (0, '老子不接我的啊')
# (0, '老婆我爱你的。')
# (0, '老婆我好想你你')
# (0, '美女我好想你。')
# (0, '第一个你大爷的')
# (0, '笨蛋你这个笨蛋')
# (0, '笨笨笨笨笨笨的')
# (0, '神经病你的大脑')
# (0, '祝福大家新年好')
# (0, '知道你妹啊现在')
# (0, '真难过我也难过')
# (0, '真是伤心之恋。')
# (0, '真无语你太蠢了')
# (0, '百度一下莫生气')
# (0, '现在就是伤心了')
# (0, '特别憋屈的地方')
# (0, '爱你发了鹤壁啦')
# (0, '漂洋过海来看你')
# (0, '漂亮的彩虹图片')
# (0, '漂亮的动物打开')
# (0, '没空理你我开车')
# (0, '没有烦恼的地方')
# (0, '没有我喜欢绿色')
# (0, '没什么我喜欢你')
# (0, '没事笨蛋没事。')
# (0, '欢欢喜喜过大年')
# (0, '棒棒宝贝宝贝。')
# (0, '晚安我爱你老母')
# (0, '是美女还是帅哥')
# (0, '是真的爱上了你')
# (0, '是不是生病了啊')
# (0, '是不是活腻了？')
# (0, '拜拜承诺帅不帅')
# (0, '所以我特别讨厌')
# (0, '我骄傲我骄傲啊')
# (0, '我还是喜欢紫色')
# (0, '我超级喜欢你啊')
# (0, '我超级喜欢你。')
# (0, '我说我也不开心')
# (0, '我讨厌你讨厌你')
# (0, '我觉得白色好看')
# (0, '我觉得特别好看')
# (0, '我觉得你是笨蛋')
# (0, '我觉得你不好啊')
# (0, '我老婆美不美啊')
# (0, '我美不美有多美')
# (0, '我管你怎么回答')
# (0, '我祝你新年快乐')
# (0, '我真的受伤了。')
# (0, '我的爸爸帅不帅')
# (0, '我的房东挺好的')
# (0, '我的心里只有你')
# (0, '我的妈妈美不美')
# (0, '我的可爱的小度')
# (0, '我的会你说我就')
# (0, '我现在好孤单啊')
# (0, '我爱你我管撤下')
# (0, '我爱你我也爱你')
# (0, '我爱你你爱我吗')
# (0, '我爱你你好帅哟')
# (0, '我爱你什么意思')
# (0, '我爱你不论贵气')
# (0, '我爱你一生一世')
# (0, '我爱你一万年。')
# (0, '我来了呵呵呵呵')
# (0, '我朝你是故意的')
# (0, '我是真的喜欢你')
# (0, '我是不是有病啊')
# (0, '我是一个穷光蛋')
# (0, '我揍我儿子行吗')
# (0, '我拼了命爱过的')
# (0, '我我爱你我爱你')
# (0, '我感觉我要感冒')
# (0, '我怎么没有看到')
# (0, '我心里的温柔。')
# (0, '我家也有小猪蛋')
# (0, '我媳妇儿生气了')
# (0, '我妈也开心起来')
# (0, '我好穷啊怎么办')
# (0, '我好烦心情好烦')
# (0, '我好想你我真笨')
# (0, '我头痛太少太少')
# (0, '我喜欢这首音乐')
# (0, '我喜欢这个曲子')
# (0, '我喜欢红色红色')
# (0, '我喜欢紫色粉色')
# (0, '我喜欢的是跑车')
# (0, '我喜欢段丽萍。')
# (0, '我喜欢明天没空')
# (0, '我喜欢天猫精灵')
# (0, '我喜欢做足疗。')
# (0, '我喜欢你喜欢你')
# (0, '我喜欢一个美女')
# (0, '我喜欢一个男生')
# (0, '我喜欢一个女孩')
# (0, '我发现你好笨啊')
# (0, '我儿子不听话。')
# (0, '我们背对背拥抱')
# (0, '我们老板喜欢你')
# (0, '我以后不要你啊')
# (0, '我也不想理你呀')
# (0, '我不需要你乖乖')
# (0, '我不是很能把握')
# (0, '我不想考虑你。')
# (0, '我不会原谅你的')
# (0, '我一根烟就恶心')
# (0, '感谢所有的朋友')
# (0, '感觉有点笨呐。')
# (0, '感觉就是不错啊')
# (0, '恭喜恭喜发财。')
# (0, '思思念念全是你')
# (0, '怕我我也不怕你')
# (0, '怎么这么聪明啊')
# (0, '怎么这么垃圾的')
# (0, '怎么舍得你难过')
# (0, '怎么怎么的好看')
# (0, '怎么办哼哼哼哼')
# (0, '怀抱了嘿嘿嘿嘿')
# (0, '快乐高兴回来了')
# (0, '心碎是什么声音')
# (0, '心痛的无法呼吸')
# (0, '彻彻底底忘记你')
# (0, '当时嘛也不讨厌')
# (0, '开开心快快出来')
# (0, '废话我也不知道')
# (0, '就是不让我回来')
# (0, '就像说不要说话')
# (0, '少年哈哈哈哈哈')
# (0, '小爱你反应迟钝')
# (0, '小智你好漂亮啊')
# (0, '小微我喜欢你了')
# (0, '小可爱，乖不乖')
# (0, '小伙子哈哈哈哈')
# (0, '小云你好靓仔啊')
# (0, '对象哈哈漂亮了')
# (0, '姑娘姑娘我爱你')
# (0, '妹妹不要来烦我')
# (0, '妈妈也是好的嘛')
# (0, '好长啊哈哈哈哈')
# (0, '好烦咯一到两天')
# (0, '好像没有了机会')
# (0, '好像你这个笨蛋')
# (0, '好了吗呵呵呵呵')
# (0, '好了不想理你了')
# (0, '好久不见我的我')
# (0, '女人女孩恐怖了')
# (0, '大头鬼小猪佩奇')
# (0, '多么美丽的景象')
# (0, '垃圾不要放空炮')
# (0, '在呢，你唱啥？')
# (0, '因为我是喜欢你')
# (0, '因为我喜欢你啊')
# (0, '嘿嘿嘿打开热点')
# (0, '嘿嘿嘿嘿嘿给亮')
# (0, '嘿嘿嘿嘿不是你')
# (0, '嘿嘿嘿嘻嘻嘻嘻')
# (0, '嘿嘿呀呀哎呀呀')
# (0, '嘿嘿你明天下午')
# (0, '嘻嘻吃饭了没有')
# (0, '喜欢里面的歌曲')
# (0, '喜欢那个白色的')
# (0, '啥玩意儿播放八')
# (0, '啊我弟弟帅不帅')
# (0, '啊我受不了你了')
# (0, '啊哈哈哈哈哈啊')
# (0, '啊你这个坑爹啊')
# (0, '啊你这个坏东西')
# (0, '唱出来哈哈哈哈')
# (0, '哼哼哼哼新年好')
# (0, '哎呀终于找到了')
# (0, '哎呀妈太吓人了')
# (0, '哎呀好使了哈哈')
# (0, '哎呀哈哈哈哈哈')
# (0, '哎呀呀说她可爱')
# (0, '哎呀别闹了墨迹')
# (0, '哎呀你挺厉害呀')
# (0, '哎呀你好可爱啊')
# (0, '哎呀你也太笨了')
# (0, '哎呀亲爱的哥哥')
# (0, '哎呀不行啊呵呵')
# (0, '哈哈打乱了我的')
# (0, '哈哈啥时候说话')
# (0, '哈哈哪个第一个')
# (0, '哈哈哈面壁思过')
# (0, '哈哈哈那个真帅')
# (0, '哈哈哈这个表情')
# (0, '哈哈哈等于一杯')
# (0, '哈哈哈没有难过')
# (0, '哈哈哈无学加油')
# (0, '哈哈哈战斗快考')
# (0, '哈哈哈哈我觉得')
# (0, '哈哈哈哈我也去')
# (0, '哈哈哈哈小说了')
# (0, '哈哈哈哈好不好')
# (0, '哈哈哈哈哈退出')
# (0, '哈哈哈哈哈开心')
# (0, '哈哈哈哈哈好笑')
# (0, '哈哈哈哈哈哈啊')
# (0, '哈哈哈哈压一压')
# (0, '哈哈哈哈什么的')
# (0, '哈哈哈哈什么嘛')
# (0, '哈哈哈呵呵呵呵')
# (0, '哈哈哈双人双人')
# (0, '哈哈哈你穿哪个')
# (0, '哈哈哈你好小子')
# (0, '哈哈哈也是三天')
# (0, '哈哈吃饭就可以')
# (0, '哈哈准备的盒子')
# (0, '哈哈你这是烦我')
# (0, '哈哈你我说错了')
# (0, '哈哈你好你可爱')
# (0, '哈哈你别说英语')
# (0, '呵呵最难三小度')
# (0, '呵呵拓海牧羊人')
# (0, '呵呵呵呵我来了')
# (0, '呵呵呵呵嘿嘿嘿')
# (0, '呵呵呵呵你休息')
# (0, '呵呵别太搞笑了')
# (0, '听不懂算了半天')
# (0, '同是天涯沦落人')
# (0, '只是别说太多了')
# (0, '取消你要是懂吗')
# (0, '发这个垃圾东西')
# (0, '反正还是亲爱的')
# (0, '反正他也喜欢你')
# (0, '厉害你你好现代')
# (0, '加油站麻痹路口')
# (0, '别烦我了天天的')
# (0, '别吵了别吵了我')
# (0, '别别别别生气啊')
# (0, '别别了哈哈哈哈')
# (0, '冯竞程小笨蛋。')
# (0, '再说一次我爱你')
# (0, '六十你别扯淡了')
# (0, '先生不要生气了')
# (0, '偏偏喜欢的座位')
# (0, '俺是不是个笨猪')
# (0, '侯铸轩不听话。')
# (0, '你长得非常好看')
# (0, '你长得也挺帅的')
# (0, '你那么烦爪子嘛')
# (0, '你这个人真烦人')
# (0, '你这个人也不行')
# (0, '你还是从前的你')
# (0, '你还是不想你我')
# (0, '你越来越聪明了')
# (0, '你说话真有礼貌')
# (0, '你说话太慢了。')
# (0, '你说了你跟他说')
# (0, '你觉得我帅不帅')
# (0, '你脑袋有点问题')
# (0, '你脑壳真的有包')
# (0, '你翻脸是一下。')
# (0, '你真的特别漂亮')
# (0, '你真的是太笨了')
# (0, '你真的不如小肚')
# (0, '你真是一个笨蛋')
# (0, '你的能力太差了')
# (0, '你的爱好是什么')
# (0, '你的废话太多了')
# (0, '你的妈妈也不大')
# (0, '你的名字太长了')
# (0, '你的反应太慢了')
# (0, '你现在这样爱着')
# (0, '你特别真的好吃')
# (0, '你有点怪怪好看')
# (0, '你有没有过敏啊')
# (0, '你普通话不行啊')
# (0, '你是神经病啊啊')
# (0, '你是最美的乡雨')
# (0, '你是什么东西啊')
# (0, '你是不是缺心眼')
# (0, '你是不是笨蛋？')
# (0, '你是不是神经病')
# (0, '你是不是生气了')
# (0, '你是不是欠揍？')
# (0, '你是不是机器人')
# (0, '你是不是有病？')
# (0, '你是不是哈批？')
# (0, '你是不是变老了')
# (0, '你是一个笨蛋。')
# (0, '你想想看为什么')
# (0, '你情商挺高的嘛')
# (0, '你怎么那么烦呢')
# (0, '你怎么那么好看')
# (0, '你怎么这么讨厌')
# (0, '你怎么这么差劲')
# (0, '你怎么这么垃圾')
# (0, '你怎么不睡觉啊')
# (0, '你怎么不听话啊')
# (0, '你居然敢骂主人')
# (0, '你居然不会生气')
# (0, '你就是老太太啊')
# (0, '你就是我的女人')
# (0, '你就是一个笨蛋')
# (0, '你实在是太笨了')
# (0, '你好道歉对不起')
# (0, '你好笨你好笨迟')
# (0, '你好白痴你好笨')
# (0, '你好搞笑点儿的')
# (0, '你好别怕你真笨')
# (0, '你好他们说话啊')
# (0, '你好不错回到了')
# (0, '你大脑打铁了。')
# (0, '你大爷的你懂啥')
# (0, '你大爷没叫你。')
# (0, '你大爷我要回家')
# (0, '你喜欢穿内衣吗')
# (0, '你喜欢我晚一点')
# (0, '你喜欢学习什么')
# (0, '你喜欢你喜欢的')
# (0, '你喜欢什么样的')
# (0, '你啥也不是啊你')
# (0, '你咋啥也干不了')
# (0, '你可是听得懂啊')
# (0, '你反应这么迟钝')
# (0, '你反应有点迟钝')
# (0, '你别说话行不行')
# (0, '你别说话我导航')
# (0, '你别说话了赶紧')
# (0, '你再说一遍试试')
# (0, '你像个啥样子？')
# (0, '你你是最丑的。')
# (0, '你们已经很棒了')
# (0, '你以为大人嘿嘿')
# (0, '你以为你脑残了')
# (0, '你为什么不想我')
# (0, '你丫根本就不笨')
# (0, '你不知道就怪了')
# (0, '你不是神经病了')
# (0, '你不听话怎么办')
# (0, '你不可我可爱。')
# (0, '你一点也不听话')
# (0, '伤感伤感干什么')
# (0, '伤心什么是苦事')
# (0, '以后不要这么晚')
# (0, '他在那里理我了')
# (0, '他们两个吵架了')
# (0, '今天心情不好。')
# (0, '什么玩意儿这是')
# (0, '什么小毛病很多')
# (0, '什么嘛你这句话')
# (0, '什么叫做听不懂')
# (0, '什么什么玩意儿')
# (0, '什么乱七八糟的')
# (0, '亿万个伤心理由')
# (0, '了不起的女孩儿')
# (0, '买菜了呵呵呵呵')
# (0, '乖乖乖乖乖乖啊')
# (0, '之前也会伤心啊')
# (0, '为什么烦人啊？')
# (0, '为什么不理我啊')
# (0, '为什么不会照相')
# (0, '世间始终你最好')
# (0, '不过我喜欢那个')
# (0, '不要脸嘿嘿嘿嘿')
# (0, '不要生气了打开')
# (0, '不要理我女儿了')
# (0, '不知道你说的啥')
# (0, '不敢不敢睡觉。')
# (0, '不想理你要睡觉')
# (0, '不好喜欢的歌曲')
# (0, '不仅仅是喜欢你')
# (0, '一生最爱的是你')
# (0, '一个美丽的传说')
# (0, '一个深爱的女孩')
# (0, '麻痹麻痹麻痹')
# (0, '麻痹打开宠物')
# (0, '高兴高兴高兴')
# (0, '非常喜欢你啊')
# (0, '难道你不懂吗')
# (0, '难道不臭脸色')
# (0, '闭嘴哪也不去')
# (0, '那真烦人你。')
# (0, '那段我喜欢你')
# (0, '那关我毛事啊')
# (0, '那也么好了呀')
# (0, '遗憾啊夸奖你')
# (0, '道理也不懂啊')
# (0, '这话也听不懂')
# (0, '这样的不理你')
# (0, '这是肌肉蠢了')
# (0, '这是什么道路')
# (0, '这是什么玩意')
# (0, '这是什么故障')
# (0, '这么厉害了。')
# (0, '这个飞翔好看')
# (0, '这个颜色好看')
# (0, '这个美美姐姐')
# (0, '还是可怜的了')
# (0, '还挺厉害的。')
# (0, '越来越生气了')
# (0, '超级宝贝舅舅')
# (0, '起来的你讨厌')
# (0, '走开走开走开')
# (0, '请问你个头啊')
# (0, '说话你听不懂')
# (0, '说你大爷葫芦')
# (0, '说个笑话听听')
# (0, '说个毛线说话')
# (0, '觉得挺好吃的')
# (0, '蟒蛇超级姐妹')
# (0, '脑子瓦特了你')
# (0, '耶耶耶耶耶耶')
# (0, '老爸是大坏蛋')
# (0, '老子没喊你。')
# (0, '老子心情不好')
# (0, '老子天下第一')
# (0, '老婆老婆你好')
# (0, '美得像的那个')
# (0, '美女性感一个')
# (0, '终于见到你了')
# (0, '纯粹的情思。')
# (0, '纯种的气人了')
# (0, '系统哈哈哈哈')
# (0, '答案是你大爷')
# (0, '笨蛋笨蛋笨蛋')
# (0, '笨蛋小院你好')
# (0, '笨蛋小度小度')
# (0, '笨蛋出去以后')
# (0, '笨蛋你是笨笨')
# (0, '笨笨笨笨笨笨')
# (0, '笑脸你好给力')
# (0, '笑一笑笑一笑')
# (0, '秀恩爱也不错')
# (0, '福特不想理你')
# (0, '神经病的事儿')
# (0, '神经病搞错了')
# (0, '神经病巴闭了')
# (0, '神经病啊你啊')
# (0, '祝您旅途愉快')
# (0, '睡不著你真乖')
# (0, '眼不见心不烦')
# (0, '真真是笨蛋。')
# (0, '真的逗狗的啊')
# (0, '真的就是好看')
# (0, '真的好想你。')
# (0, '真的呵呵呵呵')
# (0, '真是太聪明了')
# (0, '皮哟你发错了')
# (0, '白色的坏蛋啊')
# (0, '现在很烦这种')
# (0, '王海涛是笨蛋')
# (0, '王楚涵是笨蛋')
# (0, '王朝武是坏蛋')
# (0, '王八王八王八')
# (0, '王佳林是笨蛋')
# (0, '猪脑猪脑光三')
# (0, '猪猪猪猪猪猪')
# (0, '犯贱艾玛卧槽')
# (0, '爸爸呵呵呵呵')
# (0, '爱过了伤过了')
# (0, '爱过两三个了')
# (0, '爱爱你我爱你')
# (0, '爱上你是我的')
# (0, '烦不烦烦不烦')
# (0, '烦不烦没事干')
# (0, '点儿没意思的')
# (0, '漂亮的怎么了')
# (0, '浩浩大坏蛋。')
# (0, '泪泪泪泪泪泪')
# (0, '泉州有个垃圾')
# (0, '没事儿太丑了')
# (0, '江苏是坏蛋。')
# (0, '毕业我喜欢你')
# (0, '欢欢你好干净')
# (0, '来世好想你。')
# (0, '李梓硕大笨蛋')
# (0, '李云淼帅不帅')
# (0, '有你就幸福啊')
# (0, '最美的情人。')
# (0, '最好永远别见')
# (0, '智障智障智障')
# (0, '晚上心情不好')
# (0, '是神经病啊。')
# (0, '是不是垃圾啊')
# (0, '昨晚我受够了')
# (0, '春天爱是多少')
# (0, '救救我救救我')
# (0, '放首我喜欢的')
# (0, '收到哈哈哈哈')
# (0, '挺烦人的是吧')
# (0, '挺好的挺好的')
# (0, '担心的我担心')
# (0, '打开雍正恶心')
# (0, '我非常的恶心')
# (0, '我非常喜欢你')
# (0, '我遇到危险了')
# (0, '我觉得有点烦')
# (0, '我觉得太烦了')
# (0, '我觉得你最好')
# (0, '我觉得你很棒')
# (0, '我觉得你大爷')
# (0, '我要说你垃圾')
# (0, '我要生气了。')
# (0, '我老婆美不美')
# (0, '我老公是坏蛋')
# (0, '我真的喜欢你')
# (0, '我的心情很差')
# (0, '我的心好难过')
# (0, '我的外婆好烦')
# (0, '我的声音好听')
# (0, '我的哈哈哈哈')
# (0, '我爸爸爱喜雪')
# (0, '我爱你的爸爸')
# (0, '我爱你的宝贝')
# (0, '我爱你的中国')
# (0, '我爱你怎么办')
# (0, '我爱你哈哈哈')
# (0, '我爱你原来我')
# (0, '我爱你信不信')
# (0, '我爱你亲爱的')
# (0, '我没欠你的也')
# (0, '我没有挽留你')
# (0, '我欢喜喜欢你')
# (0, '我有点生气了')
# (0, '我最美的风景')
# (0, '我是舍不得你')
# (0, '我是不是很帅')
# (0, '我挺生气的。')
# (0, '我挺喜欢你的')
# (0, '我感觉很漂亮')
# (0, '我想找个美女')
# (0, '我想学你大爷')
# (0, '我怕你们真吵')
# (0, '我怎么不要脸')
# (0, '我心情不开心')
# (0, '我心情不好。')
# (0, '我就那么烦呢')
# (0, '我就让我爱你')
# (0, '我就是聪明啊')
# (0, '我就想哭一直')
# (0, '我家这边可好')
# (0, '我家就烦他了')
# (0, '我孩子不听话')
# (0, '我奶奶的拿来')
# (0, '我奶奶是笨猪')
# (0, '我奶奶喜欢你')
# (0, '我奇怪你个头')
# (0, '我太想你了。')
# (0, '我喜欢颜一彦')
# (0, '我喜欢这首。')
# (0, '我喜欢蓝色的')
# (0, '我喜欢紫红色')
# (0, '我喜欢正常的')
# (0, '我喜欢我表妹')
# (0, '我喜欢我什么')
# (0, '我喜欢听的歌')
# (0, '我喜欢你歌曲')
# (0, '我喜欢你抱抱')
# (0, '我喜欢你啊。')
# (0, '我喜我喜欢你')
# (0, '我啥也不好听')
# (1, '爱你')
# (1, '爱我')
# (1, '你好帅')
# (1, '真的爱你')
# (1, '爱你哟')
# (1, '爱你呀')
# (1, '爱你那么多')
# (1, '你是人吗')
# (1, '我爱我')
# (1, '爱')
# (1, '好想爱这个世界')
# (1, '爱妈妈')
# (1, '刚才我最喜欢你啦哈哈')
# (1, '爱你爱你爱你')
# (1, '啊我太爱你了')
# (1, '你真笨，她说')
# (1, '上我最亲爱的')
# (1, '老婆最漂亮')
# (1, '我爱彬彬秀')
# (1, '我永远爱你')
# (1, '我最喜欢你')
# (1, '我依然爱你')
# (1, '再爱你一次')
# (1, '你最爱的人')
# (1, '你最喜欢谁')
# (1, '亲人最喜欢')
# (1, '那就是爱')
# (1, '说你爱我')
# (1, '爱就爱了')
# (1, '爱你爱你')
# (1, '更爱美人')
# (1, '我的最爱')
# (1, '我爱洗澡')
# (1, '我爱我爱')
# (1, '我爱上了')
# (1, '我很爱你')
# (1, '我不爱你')
# (1, '你最爱吧')
# (1, '你最漂亮')
# (1, '也是最爱')
# (1, '简单爱')
# (1, '爱一点')
# (1, '最鲜美')
# (1, '全是爱')
# (1, '爱的')
# (1, '是个糟老头你喜欢吧')
# (1, '你会爱我到什么时候')
# (1, '你失去了最爱的人')
# (1, '爱你怎么说出口')
# (1, '爱你在心口难开')
# (1, '我最喜欢机器人')
# (1, '妈妈再爱我一次')
# (1, '你爱我还是爱你')
# (1, '你是我最爱的人')
# (1, '你是否依然爱我')
# (1, '爱一个人好难')
# (1, '我爱我的中国')
# (1, '我是真的爱你')
# (1, '她一定很爱你')
# (1, '呵呵厉害的爱')
# (1, '那你喜欢谁')
# (1, '爱美女你说')
# (1, '爱就一个字')
# (1, '爱你爱不够')
# (1, '爱你你爱吗')
# (1, '爱了就爱了')
# (1, '有你最幸福')
# (1, '最爱你的人')
# (1, '我爱你爱你')
# (1, '我们好好爱')
# (1, '你那么爱她')
# (1, '中国美的人')
# (1, '一你最可爱')
# (1, '爱你不是23天')
# (1, '谁最漂亮')
# (1, '爱是你我')
# (1, '爱你中国')
# (1, '我爱的是')
# (1, '我爱妈妈')
# (1, '我最喜欢')
# (1, '就是爱你')
# (1, '姑娘爱你')
# (1, '妈妈爱我')
# (1, '依然爱你')
# (1, '你说爱我')
# (1, '你爱我我')
# (1, '你爱我坏')
# (1, '你好帅啊')
# (1, '你好帅呀')
# (1, '你喜欢谁')
# (1, '走吧你')
# (1, '爱老婆')
# (1, '爱地图')
# (1, '爱你的')
# (1, '最好看')
# (1, '我爱他')
# (1, '我最爱')
# (1, '喜欢她')
# (1, '你爱我')
# (1, '爱你10000年')
# (1, '乱78糟')
# (1, 'find首最喜欢听的歌')
# (1, '嗯哈哈，你咋你老人就是我们店里面国通全部通知了哈。')
# (1, '对不起，我刚刚骂你了，对不起，可可爱爱的柏悦。')
# (1, '哼哼哼哼哈哈哈哈哈当然去的人多哼哼不能去')
# (1, '伤害我爱情到底是什么多少人真心爱我悲伤')
# (1, '中国你这个人怎么回事啊不好管你打车开劲')
# (1, '又没有人跟你讲话了你叫什么呢真的是')
# (1, '癞蛤蟆嘿嘿嘿嘿嘿嘿哈哈哈你爱上我')
# (1, '我生气了你不知道啊我觉得你那么久')
# (1, '很喜欢的总有男的总要爱好的了柱子')
# (1, '哈哈哈哈哈哈哈哈哈哈哈拼音怎么写')
# (1, '你咋那么讨厌你甭管了就叫爱说爱你')
# (1, '那你喊那么就是这份子吹姑娘那段')
# (1, '那个人不理你了咱就这么神经病的')
# (1, '你是男还是女哈哈自行车店我走了')
# (1, '你太坏了吧你真的是全世界最坏人')
# (1, '汉堡店呢哈哈哈哈哈哈哈哈你们')
# (1, '我最深爱的人伤，我那是这一身')
# (1, '当然了你在我心中是最漂亮的人')
# (1, '你好帅锅的哈哈就是六没事没事')
# (1, '你别再乱两个老人两个老觉睡了')
# (1, '你先别吵架了好多好多人好多车')
# (1, '那你就是跟人一样的机器人吗')
# (1, '爱你有啥事啊呵呵呵呵呵呵呵')
# (1, '最漂亮的一个地方的一个地方')
# (1, '我最喜欢吃豆豆的红豆和绿豆')
# (1, '你的耳朵是不是被人弄掉了？')
# (1, '你个黑人跟坏人那么恶心的人')
# (1, '有事你们没人，我都不见你')
# (1, '我丑哥哥好烦啊三个人找我')
# (1, '小兰那些烂人哈哈哈哈哈哈')
# (1, '唉你怎么不让人看下我的车')
# (1, '哈哈那真是咱主任认识了呗')
# (1, '哈哈哈张婷婷出来关闭不了')
# (1, '哈哈哈哈张思晨的哥哥是谁')
# (1, '口是心非了这会儿又走了呗')
# (1, '你那个臭的，真的不懂爱。')
# (1, '你是什么人啊我都不要你了')
# (1, '你什么时候是该背诵的爱你')
# (1, '这是爱啊在后头给你流量')
# (1, '美了美了我醉了醉了醉了')
# (1, '爱宝宝你好你听到没有呀')
# (1, '爱你大爷，你叫什么名字')
# (1, '最爱你的你是我最近的爱')
# (1, '是谁你去找她吧哼搞笑啦')
# (1, '我这个气球最好看不要买')
# (1, '我讨厌的人啊内存好节奏')
# (1, '我是不是心中最可爱的人')
# (1, '我好爱你啊我好喜欢你呀')
# (1, '我不要你喜欢我要你爱我')
# (1, '如果你生气了我爱厚脸皮')
# (1, '在告别初恋的爱你是不是')
# (1, '哈哈越夜越变得越来越难')
# (1, '哈哈我是醉了你吃饭了吗')
# (1, '叫我最喜欢你哪一点吗？')
# (1, '你知道我最爱的人是谁吗')
# (1, '你喊我我的爹妈也好不好')
# (1, '你们走呵呵呵呵呵呵呵呵')
# (1, '为什么我妈妈对我这么狠')
# (1, '被伤过的心还可以爱谁')
# (1, '被伤过的心可以爱谁？')
# (1, '本想那么爱你为什么？')
# (1, '最远的你是我最近的爱')
# (1, '我的天哪你最爱吃青椒')
# (1, '我爱你不是因为我爱我')
# (1, '我多想做你最爱的人。')
# (1, '我喜欢蓝色她自己挑了')
# (1, '我喜欢吃肉有没有肉卖')
# (1, '我喜欢一个女的怎么办')
# (1, '外面纷纷扰扰乱乱糟糟')
# (1, '哪个最近最喜欢哪一个')
# (1, '哈哈你是男的还是女的')
# (1, '呵呵呵呵我最喜欢他了')
# (1, '可不行人吓着你不敢六')
# (1, '你都丢了视你如命的人')
# (1, '你神经病啊一会儿唛子')
# (1, '你就是个不讲道理的人')
# (1, '你妹的她要返回主页面')
# (1, '你好好疼你有多少年了')
# (1, '为什么没有人喜欢我呢')
# (1, '错过了缘分错过了爱')
# (1, '老婆你好漂亮也很难')
# (1, '生病生病可是那份爱')
# (1, '爱你我后悔了怎么办')
# (1, '爱你亲亲几块钱一个')
# (1, '杀了你个没良心的人')
# (1, '我让她开心搞得那个')
# (1, '我爱，我说你这些好')
# (1, '我爱的人不能发网上')
# (1, '我最爱的人是周媛媛')
# (1, '我怎么这么爱跟你说')
# (1, '我好爱你不爱我爸爸')
# (1, '我会好好爱你疼你的')
# (1, '怎么我车被人都吵了')
# (1, '很无敌的帅是什么帅')
# (1, '啥锤子啊我给你锤啊')
# (1, '哈哈哈不是好多人啊')
# (1, '哇塞这是帅吗善良的')
# (1, '和佳慧的喜欢两个人')
# (1, '反正老子醉了大尺度')
# (1, '你觉得她漂亮多了啊')
# (1, '你暗恋的人还是我？')
# (1, '你是男的是女的笨蛋')
# (1, '你是个女的我问你的')
# (1, '你喜欢男的还是女的')
# (1, '不信楼是个很棒的人')
# (1, '难道爱她不答应啊')
# (1, '那最喜欢坐豪华感')
# (1, '那么爱她为什么？')
# (1, '那么你最喜欢谁呢')
# (1, '这样爱你还记得吗')
# (1, '这有那你不是人呀')
# (1, '看你她妈这是什么')
# (1, '牙医最喜欢的行业')
# (1, '爱你要怎么好好八')
# (1, '爱你爱得那么久。')
# (1, '求你不要这么恶心')
# (1, '最真的你最真的你')
# (1, '最好看的是这个车')
# (1, '最喜欢公园里面的')
# (1, '明明是她这么乖呀')
# (1, '拉维尼维修最漂亮')
# (1, '我说赖文涛帅不帅')
# (1, '我爱的人飞走了。')
# (1, '我爱宝贝我爱宝贝')
# (1, '我爱你爱的那么久')
# (1, '我最爱的人你别哭')
# (1, '我不想跟你说话人')
# (1, '很介意你必须爱她')
# (1, '就是爱我的意思呗')
# (1, '妹妹你是我的人呐')
# (1, '啊还是有点儿糟哦')
# (1, '哇塞你你好爱我呀')
# (1, '你的智商一定是零')
# (1, '你爱谁呀你爱我吗')
# (1, '你爱了不该爱的人')
# (1, '你是机器人还是人')
# (1, '你怎么是个男的呀')
# (1, '你大爷的我是男的')
# (1, '你人真好客丽丽丽')
# (1, '你也这么可爱头像')
# (1, '你为篮球你爱篮球')
# (1, '伤心的酒吧最地板')
# (1, '那什么玩意儿乱78糟的')
# (1, '那你当个女的吧')
# (1, '那些人喜欢你。')
# (1, '那么爱你为什么')
# (1, '这条街最亮的窄')
# (1, '这条街最亮的人')
# (1, '这是爱他的样子')
# (1, '神经病我是男的')
# (1, '神经病吧这个人')
# (1, '真导航岛的不准')
# (1, '看你最喜欢的歌')
# (1, '相见容易见面难')
# (1, '爱这的不了了。')
# (1, '爱我就爱了错了')
# (1, '爱你爱得好辛苦')
# (1, '爱你爱到睡不着')
# (1, '爱你好难也好苦')
# (1, '爱你只有两三天')
# (1, '爱你十分泪七分')
# (1, '最漂亮的美女图')
# (1, '最漂亮的女司机')
# (1, '最最爱的那个人')
# (1, '最喜欢的车下山')
# (1, '抢不到人哈哈哈')
# (1, '我非常非常爱你')
# (1, '我真爱我妈妈。')
# (1, '我爱漂亮的女孩')
# (1, '我爱尚北到你。')
# (1, '我爱冰冰又开始')
# (1, '我最爱的人是谁')
# (1, '我最喜欢的关系')
# (1, '我最喜欢你了我')
# (1, '我就是爽快的人')
# (1, '我家人就很讨厌')
# (1, '怎么爱你都不够')
# (1, '帅哥你好帅呀。')
# (1, '小鹅长得帅不帅')
# (1, '天气你爱我家乡')
# (1, '哎呀我好爱你呀')
# (1, '哈哈换成谁最美')
# (1, '咱俩钥匙爱你。')
# (1, '受不了这些人那')
# (1, '别说你有多爱我')
# (1, '刘子怡好喜欢你')
# (1, '切个你爱的口味')
# (1, '其实最讨厌的人')
# (1, '做个最爱你的人')
# (1, '你真爱我都来了')
# (1, '你的脚好臭啊。')
# (1, '你爱我哪一点呢')
# (1, '你最喜欢吃什么')
# (1, '你喜欢男的女的')
# (1, '他就赶紧来爱我')
# (1, '不好意思哦最爱')
# (1, '一生中最爱的人')
# (1, '奶奶你就爱你10000年')
# (1, '那些年你爱我')
# (1, '还任由你们乱')
# (1, '谁长得最好看')
# (1, '谁是最帅的人')
# (1, '让爱回到过去')
# (1, '联合爱你坐船')
# (1, '给你个嘴巴子')
# (1, '现在怕是男的')
# (1, '爱这样的爱。')
# (1, '爱情最最最。')
# (1, '爱就爱你全部')
# (1, '爱就一个字舞')
# (1, '爱你那么多。')
# (1, '爱你有多少？')
# (1, '爱你怎会失恋')
# (1, '爱上你爱我坏')
# (1, '爱一个人挺好')
# (1, '有我最亲爱的')
# (1, '最喜欢的音乐')
# (1, '我要看我的爱')
# (1, '我爱我的老公')
# (1, '我爱我的哈弗')
# (1, '我爱我媳妇儿')
# (1, '我爱媳妇是谁')
# (1, '我没那么爱你')
# (1, '我最讨厌你啦')
# (1, '我最爱的是你')
# (1, '我最爱你啦。')
# (1, '我最深爱的你')
# (1, '我抽了你笨蛋')
# (1, '我喜欢你的心')
# (2, '我靠')
# (2, '你是笨蛋吗')
# (2, '乖')
# (2, '别说话了')
# (2, '你好烦')
# (2, '靠')
# (2, '你好笨呐')
# (2, '帮我喜欢的歌')
# (2, '喜欢的歌')
# (2, '你听不懂人话吗')
# (2, '闭上你的臭嘴')
# (2, '你是神经病吗')
# (2, '你是智障吗')
# (2, '你是个猪吗')
# (2, '你耳聋吗')
# (2, '废话吗')
# (2, '啊我靠')
# (2, '烦了')
# (2, '我说你别说话啦')
# (2, '你可以做笨蛋吗')
# (2, '我靠你的嘴')
# (2, '我是帅哥吗')
# (2, '别劝我大度')
# (2, '靠你大爷')
# (2, '我靠我靠')
# (2, '老子曰')
# (2, '别狗叫')
# (2, '别废话')
# (2, '你欠骂')
# (2, '靠你')
# (2, '被发现了找不到那个恶心我了')
# (2, '呜呜我要回家了你别烦扰我啦')
# (2, '帮我喜欢听的歌')
# (2, '你觉得我漂亮吗')
# (2, '你能听懂人话吗')
# (2, '你好烦你好奔驰')
# (2, '有喜欢的人吗')
# (2, '听不懂人话吗')
# (2, '别别别我害怕')
# (2, '在吗神经病')
# (2, '你是大便吗')
# (2, '你是哑巴吗')
# (2, '你会说话吗')
# (2, '生气了吗')
# (2, '我好烦呐')
# (2, '哎呀我靠')
# (2, '别说话啊')
# (2, '你能好吗')
# (2, '你耳背吗')
# (2, '靠别克')
# (2, '靠你嘴')
# (2, '老鸹嘴')
# (2, '美女吗')
# (2, '好烦呐')
# (2, '你聋吗')
# (2, '别说话了行吗别说话了行吗想玩想玩不让玩行吗想玩上哪玩你哪有个')
# (2, '徐良布兰妮你来了你给我下个冲击咱能有啥意思吗能行吗别逗我了')
# (2, '亲，我对你生气啦，我早就被你气坏了，你跟我好好的听我的话。')
# (2, '嘻嘻哈哈哈哈帮我下载了英语帮我下载了哈哈哈哈太搞笑了')
# (2, '嘿嘿嘿嘿你来了解决不让我这个饿肚子的问题吗')
# (2, '靠你嘴巴不是那种脏不堪受不了画面不是肿的')
# (2, '爸爸说你神经病就是神经病别给我这么多废话')
# (2, '你到盘子里都是猪吗能不能一直要讲吗你执着')
# (2, '一直说一直说我靠我现在要做什么都不知道')
# (2, '我靠你不信你能到家里来我靠你行不行啊')
# (2, '我靠你有没有下载腾讯视频里下不了啊')
# (2, '你是不是上火了？你看你说话嘴那么臭')
# (2, '你是个大神经病，脑子里面被驴踢了')
# (2, '你咋听的懂你你听得懂吗我在说英语')
# (2, '阿明明天还能过来哈哈哈哈哈哈哈')
# (2, '我还以为你能拿我咒骂你听不到吗')
# (2, '你真讨厌人家来了你非要吵什么呀')
# (2, '你是一个猪哈哈哈哈哈哈哈别这样')
# (2, '然后搞个毛线啊你别说话好不好')
# (2, '曾经被妈妈戴眼镜哈哈哈哈挖挖')
# (2, '我不想见你你不回人家不管你啊')
# (2, '小小笨你知道你这样讲话击败吗')
# (2, '哼哼哼哼哼哼哼哼哼哼哼哼不来')
# (2, '哈哈那俺俩聊走以后能聊聊微信')
# (2, '哈哈哈哈零三我的皮肤就不好吗')
# (2, '你怎么会被难倒了呢？你不乖。')
# (2, '你好笨你好别这样倒车是影象吗')
# (2, '你别说话了吗你别说话了吗烦我')
# (2, '错了有毛病啊靠我看不到没错')
# (2, '烦烦烦烦烦烦烦烦烦烦烦烦烦')
# (2, '我说你脑残你是不是被你吐啦')
# (2, '我擦差点儿蹭蹭我的冲过来了')
# (2, '我想被宰呵呵呵呵哈哈哈哈哈')
# (2, '嘿嘿就一天没看看去吗那边的')
# (2, '啊睡了吗呵呵呵呵呵呵呵呵呵')
# (2, '哎呀烦什么你要说不清楚一点')
# (2, '咱们的大叔喜欢人家上地址吗')
# (2, '别那么冷我说错话了不要生气')
# (2, '你这车加油别这么烦啊这是你')
# (2, '你被别说话你说话都不明白了')
# (2, '你不要破坏这些破八者十我靠')
# (2, '小文你是听不懂我说的话吗')
# (2, '嘿嘿的师傅叫你别那么搞笑')
# (2, '哎呀我太烦了烦的跟狗一样')
# (2, '哈哈哈哈哈哈哈哈别讲话了')
# (2, '哈哈别人怎么给你了吗你帮')
# (2, '别说话了别跟他说话好不好')
# (2, '你能干嘛你这个没用的东西')
# (2, '你是个笨蛋吗好吃吗弱智吗')
# (2, '我让你别吵吵你非要吵吵')
# (2, '我要被你气晕了我不说了')
# (2, '怎么意思啊抢劫劫财了吗')
# (2, '奥特曼你听不见我说话吗')
# (2, '嘿嘿嘿你不是很聪明的吗')
# (2, '哈哈哈哈哈哈哈哈马阳阳')
# (2, '呵呵想去啊你能跟峰峰呢')
# (2, '别这样说话是不是杀了你')
# (2, '别叫他扯犊子赶紧给我发')
# (2, '你能看见我喜欢拿什么呀')
# (2, '你聋了吗怎么不回答我啊')
# (2, '你百分百生气啦还要说吗')
# (2, '你把老子这个还有好烦呐')
# (2, '你打算怎么样别那么烦你')
# (2, '你喜欢什么车子吃饭了吗')
# (2, '你可以喊你好好说话了吗')
# (2, '麻烦脱袜子了你好几天')
# (2, '那你以后能不能再气我')
# (2, '那个靠老子真是找不到')
# (2, '我靠我靠我靠我靠我靠')
# (2, '我靠我怎么知道厉害啊')
# (2, '我都被你伤痛的不能伤')
# (2, '我爱你喂喂喂帮我打开')
# (2, '嘿嘿怎么这么高兴的歌')
# (2, '哈哈哈哈哈哈逗我的吗')
# (2, '你承认你是笨蛋可以吗')
# (2, '你好意思噶可以回信息')
# (2, '那你能帮我骂骂她吗')
# (2, '让你哭的新出的歌吗')
# (2, '老子老子不再犹豫吗')
# (2, '我靠这老师不管用了')
# (2, '我靠这是不是逆行了')
# (2, '我靠我转发个信息了')
# (2, '我靠只要他们回答你')
# (2, '我靠你能不能告诉我')
# (2, '我靠你怎么不回答我')
# (2, '我脾气不好被惹我啊')
# (2, '我看你脑袋被驴踢了')
# (2, '我帮你服气了我服你')
# (2, '我就要说你管的着吗')
# (2, '怎么了靠你别说话啊')
# (2, '帮我小声一点好烦啊')
# (2, '小凯你喜欢男孩子吗')
# (2, '太坑了听不懂人话吗')
# (2, '哼哼帮我歇一会儿的')
# (2, '哎呀不要烦了我自己')
# (2, '哈哈我被怪兽抓坏了')
# (2, '哈哈哈哈哈哈来一声')
# (2, '别哼哼哼哼哼哼哼哼')
# (2, '做什么的你是笨蛋吗')
# (2, '你好笨疼，你好笨呐')
# (2, '你好像很不开心对吗')
# (2, '你听不懂我说话吗？')
# (2, '你俩又有玩的了哈哈')
# (2, '你不是喜欢吹牛吗？')
# (2, '下个想揍你是聋子吗')
# (2, '靠被你这么一打扰')
# (2, '车哈哈哈哈哈哈哈')
# (2, '谁说错了吧别讲话')
# (2, '被你弄坏了叫你说')
# (2, '能不能不要要脸了')
# (2, '没人理你赶紧回吧')
# (2, '杀人是吗小云小云')
# (2, '我骂你能听懂吗？')
# (2, '我靠不认你了打开')
# (2, '我长的挺帅的好吗')
# (2, '我昏头了都被你们')
# (2, '我叫帅哥帮我拍的')
# (2, '快点出来吗他奶奶')
# (2, '小志真棒别说话啦')
# (2, '嘿嘿小猪小猪乖的')
# (2, '嘿嘿你不是哈弗吗')
# (2, '喊我婶婶喊你乖吗')
# (2, '哎呀你真恶吗你个')
# (2, '受不了你俩那么近')
# (2, '卧槽你是神经病吗')
# (2, '别这么这么吓人呐')
# (2, '别瞎说了出去吧你')
# (2, '刚才我被吓了一跳')
# (2, '兄弟呀，想你吗？')
# (2, '你还是从前的你吗')
# (2, '你说我会喜欢你吗')
# (2, '你脑袋被驴踢了吧')
# (2, '你脑袋被驴踢了。')
# (2, '你脑子被驴踢了吗')
# (2, '你确定你会开车吗')
# (2, '你真的很漂亮吗？')
# (2, '你的主人是路痴吗')
# (2, '你喜欢小艾同学吗')
# (2, '你听得懂我说话吗')
# (2, '你刚刚是在骂我吗')
# (2, '你们别废话你说呢')
# (2, '伤心呀你吃饭了吗')
# (2, '不听话的小孩乖吗')
# (2, '我菜都吵了还能64')
# (2, '骂你能听得懂吗')
# (2, '靠靠靠靠靠靠靠')
# (2, '那你喜欢本田吗')
# (2, '那你别跟他烦吗')
# (2, '这样叫你了吗？')
# (2, '这个你听得懂吗')
# (2, '调到我喜欢的歌')
# (2, '语音你不敢说吗')
# (2, '认识你是我的缘')
# (2, '被人举报了然后')
# (2, '能骂人好不好呀')
# (2, '老子看到就回了')
# (2, '爱上你是我的鱼')
# (2, '漂亮吗人家明明')
# (2, '河男朋友漂亮吗')
# (2, '我靠你怎么知道')
# (2, '我说你别说话啊')
# (2, '我说不理你了吗')
# (2, '我觉得你有点乖')
# (2, '我被你难倒了。')
# (2, '我帮我喜欢的歌')
# (2, '我可以喜欢你吗')
# (2, '我不想说话好吗')
# (2, '开个玩笑不行吗')
# (2, '小度你别废话了')
# (2, '好靠你的嘴嘴。')
# (2, '好了你别说话了')
# (2, '女主人喜欢我吗')
# (2, '哪里的倍儿乖。')
# (2, '哈哈哈我在忙吗')
# (2, '哈哈哈他咳咳咳')
# (2, '周海霞长得帅吗')
# (2, '别那么卑鄙打击')
# (2, '别说话了说话了')
# (2, '别说话了你有毛')
# (2, '别让他们别吵了')
# (2, '别废话快点开始')
# (2, '你觉得我好看吗')
# (2, '你被个蚊子一样')
# (2, '你脑袋被驴踢啦')
# (2, '你脑袋被驴踢了')
# (2, '你脑子进水了吗')
# (2, '你脑子被门踢了')
# (2, '你脑子潮着呢吗')
# (2, '你能靠谱点吗？')
# (2, '你能不能退出去')
# (2, '你能不能太吵了')
# (2, '你能不能别吵了')
# (2, '你是欠挨揍吗？')
# (2, '你是妙龄少女吗')
# (2, '你是个糊涂蛋吗')
# (2, '你小微你真笨呐')
# (2, '你喜欢啪啪啪吗')
# (2, '你叫王八犊子吗')
# (2, '你做妈妈上哪儿')
# (2, '你俩别说话了吗')
# (2, '你你个白痴吗你')
# (2, '你个不要脸的吗')
# (2, '你不说你不会吗')
# (2, '你不是说右转吗')
# (2, '你不听话了吗？')
# (2, '你不可以说话吗')
# (2, '什么就吓哭了吗')
# (2, '丑八怪梁赐好吗')
# (2, '香樟里亲爱的')
# (2, '这不是有病吗')
# (2, '觉得挺好看的')
# (2, '脑子进水了吗')
# (2, '神经病啊不回')
# (2, '涛我喜欢的歌')
# (2, '本人要幸福吗')
# (2, '是神经病吗？')
# (2, '我靠这么麻烦')
# (2, '我靠袜子里有')
# (2, '我靠什么鬼啊')
# (2, '我长得帅吗？')
# (2, '我帮你个鬼呀')
# (2, '我好烦呐吉利')
# (3, '你听不懂人话')
# (3, '你是个笨蛋吗')
# (3, '你喜欢我吗')
# (3, '我不高兴')
# (3, '你笨吗')
# (3, '恶心的人')
# (3, '你疯了吗')
# (3, '刚才谈的事情你还真笨真坏真笨真坏')
# (3, '我说你耳朵还真有毛病')
# (3, '你耳朵怎么这么不好使')
# (3, '你脑子好笨呐')
# (3, '一个人好孤单')
# (3, '爱你没有错')
# (3, '我长得帅吗')
# (3, '哥哥不是人')
# (3, '你这个鸟人')
# (3, '你是不是人')
# (3, '你怕是疯喽')
# (3, '槽吓一跳52')
# (3, '我不开心')
# (3, '孤独的人')
# (3, '你聋了吗')
# (3, '可爱吗')
# (3, '一生最爱的人就是你')
# (3, '爱上你是一个错')
# (3, '你耳朵不好使啊')
# (3, '你一点都不可爱')
# (3, '世界上最帅的人')
# (3, '我长得漂亮吗')
# (3, '你脑子不好使')
# (3, '一个人的寂寞')
# (3, '爱过一个人')
# (3, '我还喜欢你')
# (3, '叫我打他吗')
# (3, '你是小猪吗')
# (3, '让我喜欢')
# (3, '痛苦的人')
# (3, '特别的人')
# (3, '我帅气吗')
# (3, '你漂亮吗')
# (3, '你有点笨')
# (3, '你哭了吗')
# (3, '你不是人')
# (3, '这么笨')
# (3, '我帅吗')
# (3, '你怕啥')
# (3, '喜欢写字骂你你是不是弱智别给我提这么简单的我九成九等于几')
# (3, '怕什么你是怕什么你是怕丢人还是怕什么你说不想离婚')
# (3, '讲个非常非常非常好笑的笑话让我弟弟开心一下嘿嘿')
# (3, '刚才跟你谈谈你在家伤心不伤心那个人你一个人在家')
# (3, '了了改天请你喝酒我过来还没在走动手掌挡着了')
# (3, '呵呵你心里有几你心里自己想想哈哈哈哈哈哈')
# (3, '去几个人那那个叫什么喜欢你别人家都交不起')
# (3, '我让你不寂寞满意各位你们的讲话讲的哈哈')
# (3, '我活了十年从来没见过你这种人听不懂人话')
# (3, '哎呀妈呀你看你这个人出现吗哎呀妈呀妈呀')
# (3, '叫错了我的名字但是毫不影响我继续喜欢你')
# (3, '你是神经病有毛病你半夜三更不救命的人')
# (3, '哼哼哼哼哼哼哼哼哼哼哈哈哈哈哈哈哎1加1等于几')
# (3, '我也喜欢一个人考取考科几了哦考科四')
# (3, '哈哈哈大个找人在找个哈哈哈哈我疯了')
# (3, '哈哈哈哈哈哈来一下子还不上线他们用')
# (3, '哈哈哈哈哈哈哈哈哈哈什么今天星期几')
# (3, '听不懂的你还在骂人这话这句话就是说')
# (3, '你知不知道你是我一生最爱沈浩晨唱的')
# (3, '我我怕他们怕可和了算了不提他了吧')
# (3, '哈哈哈哈哈哈哈怕空气突然安静那个')
# (3, '为什么我很怕我不可爱了我是帅哥啊')
# (3, '丰富个毛线丰富你都打错了你还丰富')
# (3, '一嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (3, '还真不喜欢老公亮瞎小羊驼小羊驼')
# (3, '在还想等几天不来你就不给了哈哈')
# (3, '哈哈你这个人怎么跟你说啊你不是')
# (3, '你正在说谎的话我就不愿意让你了')
# (3, '你是什么地方人的讲话你听不懂啊')
# (3, '一开始呵呵呵呵呵呵呵呵呵呵呵呵')
# (3, '怎么才能让我喜欢的人喜欢上我')
# (3, '喜欢这些曲子听得让人就是那种')
# (3, '做到再说一这是月亮就是嘿嘿嘿')
# (3, '你说这个人为什么会那么烦恼呢')
# (3, '你要不贵州话不标准嘿嘿嘿嘿嘿')
# (3, '你怎么舍得让我的眼泪陪你过夜')
# (3, '那些人不要嚣张了老子回来了')
# (3, '我一天气的不想理你你还你好')
# (3, '哈哈哈哈哈哈我们一起学猫叫')
# (3, '哈哈哈哈哈哈哈哈哈哈不可以')
# (3, '哈哈你是什么型的啊不知道啊')
# (3, '你脑子是不是有病听不懂人话')
# (3, '你就是脑残你就是怕我是哪个')
# (3, '你太笨了我不想让你这个朋友')
# (3, '你听不懂不懂话吗打你哦嘿嘿')
# (3, '不愿意真的不愿意再打车后面')
# (3, '那个恶心的垃圾不晓得好的')
# (3, '这个这几天不喜欢吃饭几家')
# (3, '裸睡还特别麻烦呵呵我算算')
# (3, '老婆我爱你啊让他生气漳州')
# (3, '没人敢回答满意回答不出来')
# (3, '有呀你也不痛快他还不通啊')
# (3, '我让你退出呀你还在这里烦')
# (3, '怎么还这么烦你了其实没用')
# (3, '就是怕你们在生气我不知道')
# (3, '哈哈干什么用东北话怎么说')
# (3, '哈哈哈哈哈你唱太会说话了')
# (3, '你话都不会说吗上什么学啊')
# (3, '你好笨啊你怎么听不懂话呀')
# (3, '我现在心情不高兴怎么办')
# (3, '宿舍我妈老是怕我的东西')
# (3, '因为怕伤害过来没法停车')
# (3, '哈哈妈妈可想让你学街舞')
# (3, '哈哈你不知道叫人怎么说')
# (3, '发个东北这有味儿又骂我')
# (3, '你让我很烦，你知道吗？')
# (3, '什么玩意啊我让你讲笑话')
# (3, '那我前几天不也生气了')
# (3, '李俊荣是大笨蛋吗不是')
# (3, '我觉得你一点都不专业')
# (3, '唉这点就行了你又错了')
# (3, '哈哈你用哪个字你说你')
# (3, '去你妹啊我不需要关掉')
# (3, '你这个老人家可气人了')
# (3, '你是不是听不懂人话？')
# (3, '你怎么舍得让我掉眼泪')
# (3, '你弄丢了是你如命的人')
# (3, '你大爷的你听不懂人话')
# (3, '你你是我一生最爱的人')
# (3, '什么玩意儿我也不知道')
# (3, '越秀用心爱你你不懂')
# (3, '痴心是我犯下的错。')
# (3, '玻璃吗哈哈哈哈哈哈')
# (3, '猫都怕担心了东西了')
# (3, '爱一个人真的很难吗')
# (3, '李蛋蛋掉进酒杯杯里')
# (3, '把暗示就错了你不懂')
# (3, '我好像也喜欢的人了')
# (3, '我信你个鬼还嗨你还')
# (3, '我不生气只是累而已')
# (3, '我一生最爱的人是你')
# (3, '小鬼子吗我这么烦呢')
# (3, '喜欢美女，还喜欢你')
# (3, '哈哈哈哈哈哈刚起来')
# (3, '哈哈哈不是不安全吗')
# (3, '呵呵你这个人真的是')
# (3, '你还不吵着我睡觉了')
# (3, '你让我说话他就不理')
# (3, '你的脑袋有点不好使')
# (3, '你有没有喜欢的人啊')
# (3, '你是不是听不懂人话')
# (3, '你懂错了哈哈哈哈哈')
# (3, '你怕啥这话什么意思')
# (3, '你多么舍得让我难过')
# (3, '你喜欢这里的风景吗')
# (3, '你不知道他家在哪吗')
# (3, '不跟你吵架普通话了')
# (3, '错的是你伤的是我')
# (3, '这个说话就走错了')
# (3, '还不说话还不说话')
# (3, '神经病你是什么人')
# (3, '爱上你是我的错。')
# (3, '爱上一个人有错吗')
# (3, '烦你鬼找不着不着')
# (3, '我擦我现在的人呢')
# (3, '我把真心给错了人')
# (3, '我想跟你处对象。')
# (3, '我想你的字想见你')
# (3, '恶搞了还没有消啊')
# (3, '怕你天天挺费流量')
# (3, '心里不舒坦地板槽')
# (3, '对了你还不够聪明')
# (3, '哦我到底错在哪里')
# (3, '哦哦哦不开灯呐你')
# (3, '哈哈还在家晒照片')
# (3, '哈哈哈哈还吃得起')
# (3, '哈哈哈哈呵就怕了')
# (3, '哈哈一加一等于几')
# (3, '刘英是笨笨蛋对吗')
# (3, '你耳朵怎么不好使')
# (3, '你没有错是我的错')
# (3, '你是在瞧不起我吗')
# (3, '你是一只大笨猪吗')
# (3, '你怎么听不懂人话')
# (3, '你听不懂桂林话吗')
# (3, '你不能按哪里退出')
# (3, '你不开心我开心哦')
# (3, '为什么人可以走啊')
# (3, '一亿个伤心的理由')
# (3, '错了我说的不安')
# (3, '郭富城真的怕了')
# (3, '那你脑子坏了吧')
# (3, '这让我想要快乐')
# (3, '这句话你是聋子')
# (3, '请回答你是猪吗')
# (3, '诶你还不认识呢')
# (3, '说我听不懂人话')
# (3, '老子不需要你了')
# (3, '立新长的漂亮吗')
# (3, '男人伤心不流泪')
# (3, '爱上你天大的错')
# (3, '最近的人真讨厌')
# (3, '打扰你了吗烦人')
# (3, '我的我的你的唇')
# (3, '我是听不懂人话')
# (3, '我不想话话话啊')
# (3, '怕你听不懂算了')
# (3, '怎麽舍得我难过')
# (3, '怎么还不开门人')
# ...
# (24, '美女都得过我呀')
# (24, '美女没钱呵呵。')
# (24, '绝对都不会说话')
# (24, '没听懂什么意思')
# (24, '有异性没人性啊')
# (24, '我的还没出去啊')
# (24, '太没人性听话哎')
# (24, '啊，晕了还说啊')
# (24, '哎这不是个鬼呀')
# (24, '哎呦我哈哈哈哈')
# (24, '哎呦嘿嘿去公司')
# (24, '哎听不懂说话。')
# (24, '呵呵哎呦心疼的')
# (24, '你都不搭理你了')
# (24, '你那边我喜欢这')
# (24, '你好笨升的开关')
# (24, '你喜欢薇薇吼吼')
# (24, '了没呵呵你妹啊')
# (24, '一点都不想知道')
# (24, '怎么还喜欢啊wifi刷机我从来没见过啊')
# (24, '都看不惯你了')
# (24, '都没见过你了')
# (24, '都是不好吃的')
# (24, '都什么玩意儿')
# (24, '这都不会笨蛋')
# (24, '这懂没懂啊？')
# (24, '这家伙厉害的')
# (24, '过回来啊哈哈')
# (24, '神经病这不是')
# (24, '爱上你带上钱')
# (24, '没钱不想说话')
# (24, '没感觉病啊。')
# (24, '没听见你说话')
# (24, '我这确实好用')
# (24, '我这个算吵架')
# (24, '我晕啊我晕啊')
# (24, '我是得了哈哈')
# (24, '我怎么都喜欢')
# (24, '我失恋过铃声')
# (25, '我爱你哟')
# (25, '你好棒')
# (25, '棒棒棒')
# (25, '我很喜欢你')
# (25, '我好爱你哟')
# (25, '我爱你哦')
# (25, '你好笨哟')
# (25, '爱你哦')
# (25, '你怎么这么蠢呢')
# (25, '我好喜欢你')
# (25, '你好聪明哦')
# (25, '你好可爱哟')
# (25, '我很生气')
# (25, '我很开心')
# (25, '我好伤心')
# (25, '好喜欢你')
# (25, '好漂亮')
# (25, '我现在更不开心啊')
# (25, '最近感觉好烦哦')
# (25, '我好喜欢你啊')
# (25, '我好喜欢你哦')
# (25, '我也很爱你呀')
# (25, '好喜欢你哟')
# (25, '嗯你好棒哦')
# (25, '哦你很棒呀')
# (25, '哈哈好好好')
# (25, '你好漂亮哦')
# (25, '你好可爱哦')
# (25, '我很悲伤')
# (25, '我很喜欢')
# (25, '我好生气')
# (25, '我好烦哦')
# (25, '好漂亮哦')
# (25, '好垃圾啊')
# (25, '好可爱的')
# (25, '好你大爷')
# (25, '好棒啊')
# (25, '你很乖')
# (25, '哈哈ok好')
# (25, '我很高兴认识你')
# (25, '哦呵呵呵呵呵呵')
# (25, '你怎么这么蠢啊')
# (25, '我真的很爱你')
# (25, '咱们是好朋友')
# (25, '这个小人好')
# (25, '我觉得很好')
# (25, '我好爱你呀')
# (25, '哦你好笨哦')
# (25, '你做的很好')
# (25, '我很难过')
# (25, '我很孤单')
# (25, '我很伤心')
# (25, '很舒服的')
# (25, '好幸福啊')
# (25, '好厉害啊')
# (25, '好厉害哦')
# (25, '太想爱你')
# (25, '你好笨哦')
# (25, '你好烦哦')
# (25, '你好棒啊')
# (25, '你好棒呀')
# (25, '胡叼扯')
# (25, '漂亮哦')
# (25, '好辛苦')
# (25, '好老婆')
# (25, '好宝贝')
# (25, '好可爱')
# (25, '哦哈哈')
# (25, '你好蠢')
# (25, '嘿嘿嘿嘿嘿嘿嘿嘿刚开始好吗你就好嘿嘿嘿嘿')
# (25, '我就是很坏你喜欢吗我很坏很骚你喜欢吗')
# (25, '嘿嘿嘿呵呵呵呵呵呵我好爱你哦哈哈哈')
# (25, '你好很高兴认识你呢我也很高兴认识你')
# (25, '我好生气呀我听过蹦蹦蹦蹦壳了啊')
# (25, '嘿嘿好了还有这个帽子你要带上哦')
# (25, '哦你是不是有病啊得找你混哪里啊')
# (25, '吃饭好喜欢你天气万达的天气问题')
# (25, '你个蠢你哪个嘞不晓得没得卡通勒')
# (25, '二九我要了房子也好了哦嘿嘿嘿嘿')
# (25, '好的好的好的好啊这的哈哈那我')
# (25, '哦哈哈哈哈嘿嘿下午下午干什么')
# (25, '这个好伤心哦怎么不喜欢我了')
# (25, '哟你好笑话哈哈哈哈哈哈哈哈')
# (25, '哈哈哈哈哈有意思有点意思哦')
# (25, '花开花谢你好乖哦我好喜欢')
# (25, '啊好烦啊你自己问心情好了')
# (25, '哦你们两个没吵要发的嘿嘿')
# (25, '中国人更漂亮了哦你好吉利')
# (25, '我觉得好热呀哎你好烦哦')
# (25, '我是很喜欢你才学你说话')
# (25, '我心情很不好安慰我一下')
# (25, '小薇你很可爱哟好好笑哦')
# (25, '孤芳自赏哦哦哦哦哈哈哈')
# (25, '哦这周回来了哈哈哈哈哈')
# (25, '哦哦好了好好好好嘿嘿嘿')
# (25, '你有毛病啊我也不爱你呀')
# (25, '你哈哈哈哈你好的好老婆')
# (25, '你一点都不好你好漂亮哦')
# (25, '大小鱼你真的好讨厌哦')
# (25, '啊好的好的好的哈哈哈')
# (25, '哦那你就是不会骂人哦')
# (25, '哎呀好烦躁啊我不知道')
# (25, '只能说你好棒哦来听听')
# (25, '你真笨手机连接手机好')
# (25, '你今天好漂亮哦亲爱的')
# (25, '老乡好很好很好很好')
# (25, '爱妹妹，爱妹妹哦。')
# (25, '我跟你聊天很开心呀')
# (25, '我觉得还是很伤心啊')
# (25, '我爱你哦我也爱你哟')
# (25, '我感觉你胆子好小哦')
# (25, '感觉你长得好漂亮啊')
# (25, '很厉害很厉害哟表扬')
# (25, '很厉害开车了几千了')
# (25, '好的我开心了哈哈哈')
# (25, '好爱这个地方也好啊')
# (25, '好吧好吧唉你好棒哦')
# (25, '嘿嘿嘿嘿那个好老哦')
# (25, '哦哦哈哈哈哈哈哈哈')
# (25, '哦你真棒你真会解释')
# (25, '哟你还有这么一招呢')
# (25, '你是帅哥还是美女呀')
# (25, '你是不是不听话呀？')
# (25, '你好奔驰我很喜欢你')
# (25, '老是很郁闷怎么办')
# (25, '真的很讨厌哦哼哼')
# (25, '爱你不用说出在线')
# (25, '没事了，我很伤心')
# (25, '我觉得我好幸福啊')
# (25, '我很伤心我好伤心')
# (25, '好绣花鞋哈哈哈哈')
# (25, '大连丽华园你大爷')
# (25, '哦我很喜欢你小云')
# (25, '哈哈哈哈哈哈哈好')
# (25, '哇小志你好厉害哟')
# (25, '呜呜我今天很难过')
# (25, '你真棒你好厉害哦')
# (25, '你是不是好挨揍了')
# (25, '你好漂亮好漂亮啊')
# (25, '你以为你很震惊吗')
# (25, '今天好累今天好热')
# (25, '那你更棒更棒了')
# (25, '通话好怂啊你。')
# (25, '这个真是好烦哦')
# (25, '这个是比较棒的')
# (25, '谁跟你扯一会儿')
# (25, '见联盟新年快乐')
# (25, '爸爸妈妈真笨哦')
# (25, '我说你蠢你就蠢')
# (25, '我觉得很生气了')
# (25, '我觉得你好烦哦')
# (25, '我见到你很高兴')
# (25, '我真的好害怕啊')
# (25, '我爱我的好妈妈')
# (25, '我有一个好爸爸')
# (25, '我有一个好妈妈')
# (25, '我宝贝好漂亮哦')
# (25, '怎摸这么乖呢哦')
# (25, '很高兴认识你哦')
# (25, '小瑞你好聪明哦')
# (25, '小智你好漂亮哦')
# (25, '小志你很可爱哦')
# (25, '小度我喜欢你哦')
# (25, '小度你好可爱哦')
# (25, '好想要你好给力')
# (25, '好好玩哈哈哈哈')
# (25, '好好好呵呵呵呵')
# (25, '好可爱的生意啊')
# (25, '啥子味道好臭哦')
# (25, '哦哈哈哈哈哈哈')
# (25, '哟我心疼话费了')
# (25, '哎呀哎呀好伤心')
# (25, '哎呀呀你好乖哦')
# (25, '哈哈哈哈哈好的')
# (25, '哈哈哈哈哈哈好')
# (25, '咱俩是好朋友吗')
# (25, '你长得好漂亮哦')
# (25, '你觉得很无聊吗')
# (25, '你脚丫子真臭呀')
# (25, '你真的很调皮哟')
# (25, '你真的好讨厌啊')
# (25, '你的笑容很好看')
# (25, '你的反应好慢哦')
# (25, '你就是个二球货')
# (25, '你大爷很可爱的')
# (25, '你伤心我更伤心')
# (25, '你个哈欠扯得很')
# (25, '你不信哦哈哈哈')
# (25, '好的你真棒哟100加100等于几')
# (25, '闺蜜你这么好')
# (25, '还是那么好啊')
# (25, '读书好麻烦呀')
# (25, '让你这么棒嘞')
# (25, '衣服真的爱你')
# (25, '真的真的很好')
# (25, '爱真的好爱我')
# (25, '爱你一万年。')
# (25, '更变态的烦人')
# (25, '是呀我很高兴')
# (25, '我长得很帅。')
# (25, '我觉得很搞笑')
# (25, '我真的很爱哭')
# (25, '我真的很后悔')
# (25, '我爱我的老婆')
# (25, '我爱你你爱我')
# (25, '我爱你们你们')
# (25, '我是很高兴的')
# (25, '我我很喜欢你')
# (25, '我想你爱你哟')
# (25, '我好爱你哦。')
# (25, '我好喜欢你哟')
# (25, '我好喜欢你呀')
# (26, '你有病啊')
# (26, '你有病')
# (26, '你有病吗')
# (26, '有毛病')
# (26, '你有毛病')
# (26, '你有毛病啊')
# (26, '你有病吧')
# (26, '你有毛病吧')
# (26, '你有毛病吗')
# (26, '你是有病吗')
# (26, '你有病呀')
# (26, '我有神经病')
# (26, '你有病啊你')
# (26, '你是笨鸟吗')
# (26, '你太笨了吧')
# (26, '不是因为你太笨吗')
# (26, '有多有毛病吗')
# (26, '你有神经病吗')
# (26, '你有神经病')
# (26, '你有病吧你')
# (26, '你哑巴了吗')
# (26, '你脑残吗')
# (26, '你真有病')
# (26, '我美吗')
# (26, '你爹')
# (26, '你是不是脑子有问题')
# (26, '老婆咱俩绝交吧')
# (26, '你脑子有问题吗')
# (26, '你脑壳有问题啊')
# (26, '你的智商有问题')
# (26, '你长得漂亮吗')
# (26, '你脑子有毛病')
# (26, '你耳朵有毛病')
# (26, '你智商有问题')
# (26, '你喜欢帅哥吗')
# (26, '有神经病的')
# (26, '我说你有病')
# (26, '天天有美女')
# (26, '你脑有病啊')
# (26, '你会走人吗')
# (26, '有毛病啊')
# (26, '有哈哈')
# (26, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈有什么就是')
# (26, '我爱你你哪量到洛阳了吗得了吗这有一个两到哪了')
# (26, '我知道有一万个哈哈哈哈哈哈哈哈哈笑话哈哈哈')
# (26, '你有病吗要是有病的话我我让你上找亮剑')
# (26, '哈哈小杜你有压岁钱吗哈哈哈哈哈哈哈')
# (26, '附近有美食吗呵呵哈哈哈哈哈哈哈')
# (26, '我怕你有病吧，我跟我爸爸说的')
# (26, '你你有病吧你你就到那边玩好了')
# (26, '老子说了你不听吗有什么办法')
# (26, '有笨蛋天天问的问题退出退出')
# (26, '够了够了够了我诅咒你了加油')
# (26, '嘿嘿有点甜现在天天想着出去')
# (26, '你有男朋友呵呵呵呵呵呵呵呵')
# (26, '那个你有病啊你看你呀你呀')
# (26, '哎你刚干嘛去了你有病吧你')
# (26, '哈哈一口一句的时候会退出')
# (26, '你聪明得不得了我整不过你')
# (26, '你有病呀要不要现在打不通')
# (26, '你有毛病吗你邓州不是郑州')
# (26, '你是有毛病啊，是不是啊？')
# (26, '你可真是一个坏蛋你有病吧')
# (26, '我喜欢有食物香味的地方')
# (26, '副驾驶的人脑子有问题吗')
# (26, '你的脑子是不是有问题了')
# (26, '你有病吗？你真有病啊。')
# (26, '你家有娃哈哈哈哈哈哈哈')
# (26, '今天都有什么好玩儿的吗')
# (26, '运气毛钱我有大姨妈吗')
# (26, '神经病啊你有神经病吗')
# (26, '病不敢做出太大的最低')
# (26, '我的大片你不知道吗？')
# (26, '嘿嘿玩家老玩家有多少')
# (26, '哎呀你真是脑子有问题')
# (26, '刚才不要乱骂人是不是')
# (26, '你还是有点智商的吗？')
# (26, '你脑子是不是有问题啊')
# (26, '你耳聋吗你耳朵聋了吗')
# (26, '你有病，你脑子不知道')
# (26, '你有病吧我没跟你说话')
# (26, '你有病吧你不给我抄吧')
# (26, '你是不是脑子有问题啊')
# (26, '你是不是耳朵有问题啊')
# (26, '你是不是老壳有问题啊')
# (26, '你咋不说话？你不有病')
# (26, '陈哈哈有几个女朋友')
# (26, '说你有毛病我有毛病')
# (26, '我赌你枪里没有子弹')
# (26, '我有多怕多怕多怕了')
# (26, '我感觉你有毛病是吧')
# (26, '小志小志你是美女吗')
# (26, '妮子成了吗哈哈哈哈')
# (26, '哎呀厕所你有病啊小')
# (26, '哈哈我好像我赌一场')
# (26, '你脑子是不是有问题')
# (26, '你耳朵是不是有问题')
# (26, '你耳朵是不是有毛病')
# (26, '你的脑袋是生锈了吗')
# (26, '你现在有点讨厌了吗')
# (26, '你有病么你听见没有')
# (26, '你有毛病啊你好吉利')
# (26, '你有什么好玩的功能')
# (26, '你是不是脑子有毛病')
# (26, '你恐怕脑子有问题吧')
# (26, '你好你喜欢刘德华吗')
# (26, '你太笨了吧你太笨了')
# (26, '你又不笨你有病你呢')
# (26, '你以为我长得漂亮吗')
# (26, '今夜你会不会想起我')
# (26, '不是不想遇见我的吗')
# (26, '要不说你有病有病')
# (26, '有那个吗垃圾有病')
# (26, '有了宝宝嘿嘿嘿嘿')
# (26, '我爱你罗斯有多少')
# (26, '我心里有你你有我')
# (26, '哎呀你脑子有毛病')
# (26, '你脑子有问题啊？')
# (26, '你脑子有问题吗？')
# (26, '你的脑袋有问题吗')
# (26, '你有病啊那么累啊')
# (26, '你有病吗有必要吗')
# (26, '你有病你有病啊你')
# (26, '你又有毛病了是吧')
# (26, '退出吧退出再见')
# (26, '老徐长得漂亮吗')
# (26, '真的是个脑有病')
# (26, '有那么一点喜欢')
# (26, '有毛病你好奔驰')
# (26, '有吗呵呵谢你了')
# (26, '我长得漂亮吗？')
# (26, '我长得好看吗？')
# (26, '我说你有毛病吗')
# (26, '我老婆是笨蛋吗')
# (26, '感谢有你的歌。')
# (26, '小芳你是笨蛋吗')
# (26, '小志你是坏蛋吗')
# (26, '嘻嘻王龙有多长')
# (26, '哼哼哼有哪位了')
# (26, '哎呀你是笨蛋吗')
# (26, '你长得太漂亮吗')
# (26, '你脑子有问题。')
# (26, '你脑子有病是吧')
# (26, '你脑子有毛病啊')
# (26, '你的脑子有问题')
# (26, '你的大脑有多大')
# (26, '你有神经病是吧')
# (26, '你有神经病吗？')
# (26, '你有病病没有？')
# (26, '你有病是不是啊')
# (26, '你有病嘞你你说')
# (26, '你有病啊动画片')
# (26, '你有病吧这种话')
# (26, '你有病吧没叫你')
# (26, '你有病吗有病吗')
# (26, '你有病你有病吗')
# (26, '你有病你我乱带')
# (26, '你有喜欢的女人')
# (26, '你有什么好的吗')
# (26, '你智商有问题啊')
# (26, '你是有多有病吗')
# (26, '你喜欢你姓什么')
# (26, '你你你你有病啊')
# (26, '你今天开心吗？')
# (26, '你个有病的小度')
# (26, '你不是有小猪吗')
# (26, '那你呢有病啊')
# (26, '还有病你有病')
# (26, '脑子有毛病啊')
# (26, '病你有神经病')
# (26, '爸爸你有病啊')
# (26, '有那么厉害的')
# (26, '有的好开心啊')
# (26, '有病吧神经病')
# (26, '有熊二的小猪')
# (26, '有什么白痴啊')
# (26, '有什么好气的')
# (26, '有什么哈哈哈')
# (26, '晚安你有病吧')
# (26, '推荐你很有病')
# (26, '我长得有多帅')
# (26, '我这么厉害吧')
# (26, '我说你有病吗')
# (26, '我觉得有真爱')
# (26, '我要你有何用')
# (26, '我有等会生气')
# (27, '你好烦啊')
# (27, '耶')
# (27, '你好笨呀')
# (27, '你妹呀')
# (27, '你说话呀')
# (27, '好笨呀')
# (27, '谁跟你说话呢')
# (27, '谁是大笨蛋呀')
# (27, '烦不了退出')
# (27, '你喜欢谁呀')
# (27, '我都喜欢')
# (27, '你好笨呢')
# (27, '你好好烦')
# (27, '人家烦了')
# (27, '谁叫你')
# (27, '你烦耶')
# (27, '烦啊')
# (27, '喜')
# (27, '不要烦我不要问我')
# (27, '谁跟你说话呀')
# (27, '你叫什么呀')
# (27, '不想说话呀')
# (27, '谁让你说')
# (27, '谁叫你了')
# (27, '谁叫他了')
# (27, '叫我美女')
# (27, '你骂谁呢')
# (27, '你说谁呢')
# (27, '烦你了')
# (27, '恩爱呀')
# (27, '喜欢谁')
# (27, '连你的护体真气都破不了就是你站在那里让我砍我就能拿你怎么样')
# (27, '谁是谁爸呀你真发吗你爸呢你爸你爸呢你爸你爸爸呢你爸爸是谁')
# (27, '你干什么呢是不是不舒服啊连起来又跟人都不好使什么都不正常')
# (27, '为什么呢你就叫我做的这么优秀你还讨厌我但我又怎么这么烦呀')
# (27, '诶呀我反应歌曲你昨天让你别吭气啊开车我演示最烦的就是这')
# (27, '你说你聪明为什么我刚刚问你的问题你都没答上来')
# (27, '是老子老子的谁呀你管我是谁我是谁你不用你管')
# (27, '哈哈哈啊哈哈有病有病病猜猜我是谁猜猜我是谁')
# (27, '哈哈哈哈哈哈你的爸爸是谁你的爸爸是谁你问她')
# (27, '你和你真笨呀，千千万万都不会唱，我是叫你唱')
# (27, '谁知道烦人你都不理我你可烦人了你知不知道')
# (27, '他们就是个小笨蛋呢，他问的问题你都答不到')
# (27, '我就想叫我妈妈我就要叫妈妈叫妈妈还吓人')
# (27, '我都简直这么慢你都听不懂我怎么再慢呢')
# (27, '我都恨你了你都不跟我家的天猫精灵一样')
# (27, '你真漂亮呀你的名字叫什么呀要不然我就')
# (27, '你怎么这么笨呢叫了这么多次你也听不到')
# (27, '烦烦烦烦烦烦烦烦烦烦烦烦烦烦烦烦烦')
# (27, '搞笑大声一点销售呢你根本就懒得管了')
# (27, '哈哈哈哈哈哈哈哈哈哈哈哈怎么出来呢')
# (27, '你那个普通话的便便不了哈哈哈哈')
# (27, '你有毛病叫在家又没叫你神经病啊')
# (27, '你是谁呀这么恶心你爹叫什么名字')
# (27, '你扯淡，你刚才叫你都不答应我。')
# (27, '精神病啊谁问你啥了你说什么呢')
# (27, '我靠，你这个让我很为很无语呀')
# (27, '哎呀我好烦呀总有小雪打游戏后')
# (27, '哈哈有点坑爹呀你叫我吃饱了吗')
# (27, '干嘛呢啊哈哈哈哈哈哈哈哈哈')
# (27, '女主人叫你你为什么不答应呢')
# (27, '大武口重庆哎呀你烦什么烦呀')
# (27, '你干嘛叫你叫的他都不听话了')
# (27, '为什么每次叫你你都不应呢？')
# (27, '为什么我跟你讲话你都不理我')
# (27, '飞车你你哑巴呀你不说话啊')
# (27, '这个社会给我养老嘿嘿嘿嘿')
# (27, '每天都开心每天都快乐哈哈')
# (27, '我长大我都烦了，你咋样？')
# (27, '我超级讨厌你你不要烦我呀')
# (27, '你这种问题你什么都干不了')
# (27, '你让我伤心到底什么时候呀')
# (27, '你是不是想让我气坏身子呀')
# (27, '你好烦啊为什么要说你好啊')
# (27, '贪婪的吸收了谁都不过去')
# (27, '谁跟你说话了这个小女子')
# (27, '谁谁让你惹我儿子生气了')
# (27, '很高兴认识你啊你是谁呀')
# (27, '哈哈请你吃便便哈哈哈哈')
# (27, '哈哈哈哈哈哈哈哈九天呢')
# (27, '别烦我我问一下不问不问')
# (27, '你这个桥的灯一看很漂亮')
# (27, '你的耳朵是不是不太好呀')
# (27, '领克你觉得你帅不帅呀')
# (27, '要是喝酒醉了嘿嘿嘿嘿')
# (27, '我问你你是不是神经病')
# (27, '我也很高兴跟你聊天呀')
# (27, '哎哟老爸呀都烦你了呀')
# (27, '哈哈那你还让我贴的了')
# (27, '哈哈哈你刚刚那位是谁')
# (27, '你问他我说你那叫啥呀')
# (27, '你老是走神呀你老犯错')
# (27, '你最喜欢的歌星是谁呀')
# (27, '你不要老是烦我行不行')
# (27, '都是不错的不要烦我')
# (27, '谁叫你没叫你啊拜拜')
# (27, '让你美得你的电脑。')
# (27, '耶嘿嘿嘿嘿嘿嘿嘿嘿')
# (27, '打芝种类你这么烦呀')
# (27, '哎呀好烦你哎谁叫你')
# (27, '你是美女还是男生呢')
# (27, '你怎么舍得让我难过')
# (27, '你好讨厌呀你不理我')
# (27, '你好好烦今天多少度')
# (27, '你为什么招架不住呢')
# (27, '你为什么不理我呀？')
# (27, '一直都是不要乱说话')
# (27, '一个一个都不是疯狗')
# (27, '闭嘴你的主人是谁')
# (27, '这个坏蛋让你过来')
# (27, '谁跟你说话呢退出')
# (27, '谁跟你说话了呀？')
# (27, '欢欢你去问谁搞的')
# (27, '我靠，谁可以叫了')
# (27, '我要懂了问你干嘛')
# (27, '我生气了怎么办呢')
# (27, '我一个人好寂寞呀')
# (27, '帮你跟谁个无聊的')
# (27, '嘿嘿嘿嘿怎么断了')
# (27, '哈哈的睡觉了不呀')
# (27, '听不懂啊你叫什么')
# (27, '叫大哥你都不理我')
# (27, '你这个笨蛋连打开')
# (27, '你怎么那么聪明呀')
# (27, '你什么都不会高丽')
# (27, '你不要烦我好不好')
# (27, '问你妹啊问问问')
# (27, '长兴谁不是搜狗')
# (27, '都回答不了有人')
# (27, '那谁叫你神经病')
# (27, '连个畜生都不如')
# (27, '这么叫你在啥呢')
# (27, '谁跟你说话了？')
# (27, '谁让你弄疯吗？')
# (27, '谁的人生不孤独')
# (27, '谁在意我的眼泪')
# (27, '管你大爷叫出来')
# (27, '笨蛋什么都不会')
# (27, '是谁呀有点蠢哟')
# (27, '我让你不用去呀')
# (27, '我觉的不好听呀')
# (27, '我现在特别烦你')
# (27, '怎么骂人呢制造')
# (27, '怎么还要还要管')
# (27, '怎么什么都没有')
# (27, '干嘛就是不行呀')
# (27, '干什么呀你叫她')
# (27, '姑姑喜欢谁呀？')
# (27, '喜欢谁的差不多')
# (27, '唉你都没有问呢')
# (27, '哈哈哈中心是谁')
# (27, '哇塞你好厉害呀')
# (27, '叫我爸太烦人了')
# (27, '叫什么呢都不懂')
# (27, '你都没有回答我')
# (27, '你是不是有病呀')
# (27, '你怎么不灵敏呢')
# (27, '你好小智说话呀')
# (27, '你别说话谁说话')
# (27, '你全家都叫王八')
# (27, '你以为谁都像你')
# (27, '你不要管这里的')
# (27, '亲爱的谁叫你啦')
# (27, '为啥呀我都忘了')
# (27, '不要烦我了再见')
# (27, '不要烦了好不好')
# (27, '还有我今天烦')
# (27, '谁都帮不了你')
# (27, '谁跟你讲话呀')
# (27, '谁让你说话呀')
# (27, '谁呀么叫你吗')
# (27, '让我喜让我忧')
# (27, '没人叫你美女')
# (27, '毛玩什么呀？')
# (27, '每次都要麻烦')
# (27, '我闹心挠我呀')
# (27, '我谁都不记得')
# (27, '我要跟你说话')
# (27, '我现在烦我烦')
# (28, '赞')
# (28, '你不喜欢我')
# (28, '我喜欢听')
# (28, '哈喽哈喽')
# (28, '这个不好听')
# (28, '赞一个')
# (28, '嘻嘻嘻')
# (28, '你太笨了我要你何用')
# (28, '哼哼哈哈喽h哈喽')
# (28, '哈喽你个头')
# (28, '你要干什么')
# (28, '你要不要脸')
# (28, '哈你个头')
# (28, '你不说话')
# (28, '不要放了')
# (28, '垃圾成')
# (28, '吓着了')
# (28, '你是神经病啊你咋不给我放那个')
# (28, '哈喽哈喽哈喽哈喽哈喽')
# (28, '我想你想了那么久')
# (28, '我今天不高兴')
# (28, '唱我喜欢的歌')
# (28, '哈喽哈喽哈喽')
# (28, '你妹的不敢开')
# (28, '哈嘿嘿嘿嘿')
# (28, '一晃就老了')
# (28, '非常的帅')
# (28, '我这么乖')
# (28, '你要干嘛')
# (28, '很可爱小狗还是闭著眼伸着舌头在睡觉可长啊她听不到你说话')
# (28, '哈哈我也会开了你要被拆了驾照拿到没拿到啊哪个时候开花')
# (28, '你家你非得要歌你也不给咋不给你用我家调了我不想吵了')
# (28, '要结婚了笨鸟先飞哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈')
# (28, '哇这么丑啊我靠这边还亮着啊这个时候不要发漂亮哈')
# (28, '哈哈哈嘻嘻嘻哈哈哈嘻嘻嘻嘿嘿嘿嘿嘿嘿嘿嘿哈哈')
# (28, '哈哈哈哈哈哈哈哈哈哈这里有个小度小度放音乐吧')
# (28, '就听嘿嘿嘿哈哈哈哈哈哈第二条要有就请我咱俩')
# (28, '大别吵了你还听雪宝宝你又不听我就不给你发了')
# (28, '哈哈哈哈哈哈哈哈我现在就联系下抓紧哈')
# (28, '假的哈哈哈然后他就知道你让你回家哈')
# (28, '西游记西游记西游记妈呀乖呀乖乖乖')
# (28, '哪个拉丁啊要倒霉了哈哈哈哈哈哈哈')
# (28, '我要我要喝水嘿嘿嘿嘿嘿嘿嘿嘿嘿')
# (28, '哎呀你干嘛流氓啊药量要不要一把')
# (28, '你怎么不听你主人的话老听我的话')
# (28, '什么哈喽哈喽的我也没说什么哈喽')
# (28, '要不在空调来着呢嘿嘿嘿嘿嘿嘿')
# (28, '老校区啊嗯这个很好笑就知道吧')
# (28, '哈哈人家的娘为难了我退出退出')
# (28, '你说你要再不听话我就唱五指山')
# (28, '打乒乓球着思泉奶奶哈哈哈哈')
# (28, '啊哈哈哈哪个地方我不知道啊')
# (28, '你说我喜欢听什么歌我喜欢听')
# (28, '我说话你到底听不听得懂？')
# (28, '我怕瞅瞅我也没说我怕吵着')
# (28, '发现这个竟然说话不想听了')
# (28, '你哈哈不我要听明天会更好')
# (28, '你什么要不要给我发红包？')
# (28, '真是精神喜欢听节奏快的')
# (28, '本地这些垃圾都成了这样')
# (28, '我想投诉你，怎么投诉？')
# (28, '我喜欢你素质毛宁听我的')
# (28, '对了你真棒我给你点个赞')
# (28, '在你大爷讲个笑话给我听')
# (28, '呵呵呵呵呵呵呵呵我要听')
# (28, '你要你要抽鸟后飞哈哈哈')
# (28, '你爱着你一个人就够了哈')
# (28, '要不你还是把我杀了吧')
# (28, '老子现在不想听你说话')
# (28, '空调对着毛毛放哈哈哈')
# (28, '小时候感情喜欢听什么')
# (28, '头疼你说的话听不清楚')
# (28, '因为碍不着我就想你了')
# (28, '哈喽哈哈哈喽哈喽哈喽')
# (28, '哈哈哈哈哈，听着呢。')
# (28, '哈哈哈哈哈哈哈哈哈喽')
# (28, '你要不喜欢我现在生气')
# (28, '你神经病啊唱什么歌呢')
# (28, '你现在开的什么东西？')
# (28, '你哈哈哈你哈啥呢你哈')
# (28, '你不要老废话行不行？')
# (28, '不好听嘿嘿嘿嘿嘿嘿嘿')
# (28, '赞你个头啊赞赞赞赞')
# (28, '现在我不喜欢扎头发')
# (28, '晚上晚上吓人了哈喽')
# (28, '我讨厌怎么老不听话')
# (28, '我艹的缺点就会听啊')
# (28, '开什么玩笑要你来吗')
# (28, '嘻嘻嘻嘻嘻嘻嘻嘻嘻')
# (28, '哼哼哼哼哼哼唱唱歌')
# (28, '哎呀你是听了聪明的')
# (28, '哈喽哈啥玩意儿小杜')
# (28, '你是个狗你飞不起来')
# (28, '这汉子这听不明白')
# (28, '请帮我放我生气了')
# (28, '请你体谅我讨厌你')
# (28, '爱你哦我要听笑话')
# (28, '拜拜我爱你拜拜喽')
# (28, '嘿嘿唱不了的到来')
# (28, '哈喽哈喽哈喽哈喽')
# (28, '哈哈哈哈放首歌听')
# (28, '哈哈哈你开了哈哈')
# (28, '哈乖乖乖乖第一个')
# (28, '呵呵呵呵那英的歌')
# (28, '你要讲话要讲好吗')
# (28, '你要唱什么快说啊')
# (28, '你要听话你要乖吗')
# (28, '你给我买哈，宝贝')
# (28, '你就乖啦我在听呢')
# (28, '你喜欢听什么歌呀')
# (28, '你一个劲闹心请你')
# (28, '乖乖乖乖乖乖乖。')
# (28, '那你给我卖个萌')
# (28, '请开启自毁系统')
# (28, '我爱你刘程程。')
# (28, '我听不到你说话')
# (28, '想想着你亲爱的')
# (28, '心里充满着希望')
# (28, '嘿嘿这些模式就')
# (28, '嘿嘿听着把把子')
# (28, '哼哼哼哼要干嘛')
# (28, '哈喽哈喽我想你')
# (28, '哈喽哈喽哈哈喽')
# (28, '哈哈还是不成功')
# (28, '哈哈哈哈我要听')
# (28, '哈哈哈哈哈哈服')
# (28, '哈哈哈哈不知道')
# (28, '哈你哈哈哈哈哈')
# (28, '听不到你太蠢了')
# (28, '你要讲跪着好吗')
# (28, '你是个老流氓不')
# (28, '你怎么那么乖了')
# (28, '你为什么要这样')
# (28, '你不乖我不哭啦')
# (28, '一晃就老了打开')
# (28, '上海现在躺着ou说开大的嘿嘿嘿嘿嘿嘿')
# (28, '这个歌不好听')
# (28, '这个卵子你飞')
# (28, '请你不要生气')
# (28, '老垃圾啊垃圾')
# (28, '给我找个美女')
# (28, '百度的不好听')
# (28, '我躺着都痛啊')
# (28, '我竟无言以对')
# (28, '我就喜欢嘻嘻')
# (29, '哼哼哼哼哼哼哼哼哼哼哼哼哼')
# (29, '我不跟你玩了')
# (29, '一点都不好')
# (29, '我不开心怎么办')
# (29, '你永远不懂我')
# (29, '你就是个脑残')
# (29, '闭嘴都不会')
# (29, '不跟你说话')
# (29, '不跟你聊了')
# (29, '我不喜欢经济界关闭')
# (29, '遗忘遗忘都遗忘')
# (29, '算了不跟你聊了')
# (29, '真的不需要呵呵')
# (29, '用心爱你你不懂')
# (29, '哼我不跟你玩了')
# (29, '我今天不开心')
# (29, '我不跟你说了')
# (29, '我不跟你玩啦')
# (29, '你什么都不懂')
# (29, '我不跟你讲')
# (29, '哼不理你了')
# (29, '不跟你玩了')
# (29, '不想跟你聊')
# (29, '不和你聊了')
# (29, '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈人家都没学没有这个职业')
# (29, '怎么不会说话说话啊怎么不说话啦怎么不说话了这个你就不说话')
# (29, '你又不你又不在我姐不在我更不淡定啊是啊哎呀我竟然没发现')
# (29, '唉我不想说话了不跟你玩我不跟你说话不想跟你说话一个')
# (29, '啊你给我压出来呀哼不跟你玩了不跟你玩儿了办理')
# (29, '我不讲文明我不懂你你骂我还不跟你一起和好')
# (29, '你看看有有哦哦哦烦了我不管你不跟你们玩了')
# (29, '暂时来不的咱俩玩好不好呵呵哈哈哈哈哈哈')
# (29, '因为鬼子骂人的话你不能讲的什么都不知道')
# (29, '搞了几个超级呵呵呵呵呵呵呵呵呵呵呵呵')
# (29, '垃圾桶那我不跟你玩了我要我要跟你决斗')
# (29, '你两个小子都没和不认识了呵呵呵呵呵呵')
# (29, '那你为什么那时候不跟你玩了我生气了')
# (29, '我不懂你不跟你玩啊不找你我不跟你玩')
# (29, '嗯我不开心那你我就不跟你聊了拜拜喽')
# (29, '为什么你老是好欺负我我不跟你玩了哼')
# (29, '我的脑袋反应很慢的你不可以笑话我')
# (29, '我不知道呵呵呵呵呵呵呵呵呵呵呵呵')
# (29, '哈哈哈你再改一个名字不改了不改了')
# (29, '你是不是欠扁啊？半天都不说话了。')
# (29, '你个不懂我后头我后头是不是我去了')
# (29, '我跟你说话没有你怎么不搭理我啊')
# (29, '那这个还真好怕你都不跟我睡觉')
# (29, '那你生了你太脏啦我不跟你说话')
# (29, '啥都没有说你都不懂你咋那么蠢')
# (29, '呵呵呵呵呵呵呵呵你什么都不懂')
# (29, '那小豆豆整个哈哈哈哈是不是')
# (29, '哼哼哼哈哈哈二头是什么意思')
# (29, '你怎么这么笨，什么都不懂。')
# (29, '你刚才为什么不回答我的问题')
# (29, '我都跟你说话，你在啥子？')
# (29, '太可怕了你自己都不出去啊')
# (29, '哈哈哈哈哈哈哈哈不跟你玩')
# (29, '哈哈你好好笑我什么都不懂')
# (29, '你咋这么小都不懂你要淡定')
# (29, '不要嫌弃我太烦就改了去玩')
# (29, '那我跟你吵架你不跟我玩')
# (29, '我好喜欢你不过你得陪我')
# (29, '我不跟你说了我要开车了')
# (29, '大笨蛋你都不懂啊有礼貌')
# (29, '哈哈哈哈哼哼哼哼哼哼哼')
# (29, '你笨蛋你都不知道你几岁')
# (29, '你是不是智商跟度假一样')
# (29, '你太笨了我不想跟你说话')
# (29, '不喜欢你了，哼，垃圾。')
# (29, '那你为什么不听我的话')
# (29, '我生气了不想聊了拜拜')
# (29, '我不是不跟你说话了吗')
# (29, '怎么老子今天不下楼了')
# (29, '哈哈哈改过错了改错了')
# (29, '你是第一个问都不知道')
# (29, '你反正每天都哈哈哈哈')
# (29, '跟你说了你都不理我')
# (29, '模式我能跟你生气了')
# (29, '我看你一点都不聪明')
# (29, '我不开心没有驾驶证')
# (29, '屌丝你都不听我的呢')
# (29, '哼哼哼嘿嘿嘿嘿嘿嘿')
# (29, '哼哼哼不知道去不去')
# (29, '哈哈哈哈哈各种不懂')
# (29, '哈哈你们还要怎么玩')
# (29, '你怎么不跟我说话你')
# (29, '你怎么不跟我说话了')
# (29, '你不我不想跟你说话')
# (29, '你一点都不聪明笨蛋')
# (29, '不呵呵是母猪的笑声')
# (29, '那玩意儿都肚子痛')
# (29, '越用心爱你你不懂')
# (29, '我的爱为何你不懂')
# (29, '我想让你陪我去玩')
# (29, '我不需要你的帮助')
# (29, '小猪你跟我说说话')
# (29, '对不起什么都不要')
# (29, '因为你不陪我们玩')
# (29, '嗨，我不跟你说话')
# (29, '你都不跟我说话了')
# (29, '你还不懂你烦不烦')
# (29, '你旺我不想见到你')
# (29, '你怎么什么都不懂')
# (29, '你为什么不搭理我')
# (29, '你不懂你听得懂吗')
# (29, '为什么你都不知道')
# (29, '不跟你聊天了再见')
# (29, '不说了不跟你聊了')
# (29, '不伤心我不相信你')
# (29, '那我不跟你玩了')
# (29, '谁不虚伪不虚伪')
# (29, '神经病懂了没有')
# (29, '玩不了就别玩了')
# (29, '抱歉不懂我的人')
# (29, '我要跟你分别了')
# (29, '我激动得都跑了')
# (29, '我浑身都不舒服')
# (29, '我求你了你不你')
# (29, '我想跟你一起玩')
# (29, '我不跟你聊天了')
# (29, '我不想陪你聊天')
# (29, '我不想跟你说话')
# (29, '我一点都不高兴')
# (29, '怎么跟你聊天啊')
# (29, '对不起我不高兴')
# (29, '哼我不跟你好了')
# (29, '哈哈哈哈播放量')
# (29, '再也不喜欢你了')
# (29, '你跟他玩你管的')
# (29, '你怎么不说话了')
# (29, '你得听话知道不')
# (29, '你妹的都是废话')
# (29, '你一点都不聪明')
# (29, '为什么不说话了')
# (29, '为什么不喜欢？')
# (29, '不要跟我说话了')
# (29, '不开心乱七八糟')
# (29, '都不会跟你吵')
# (29, '那我舍不得你')
# (29, '那不错啊不错')
# (29, '跟我说句话了')
# (29, '祝你玩得开心')
# (29, '爱上你不回头')
# (29, '永远都不理你')
# (29, '打你我不玩了')
